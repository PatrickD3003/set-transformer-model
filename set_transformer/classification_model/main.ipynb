# %%
# !pip install openpyxl
# Out:
# Requirement already satisfied: openpyxl in /Users/patrickdharma/anaconda3/envs/sousei/lib/python3.9/site-packages (3.1.5)
# Requirement already satisfied: et-xmlfile in /Users/patrickdharma/anaconda3/envs/sousei/lib/python3.9/site-packages (from openpyxl) (2.0.0)

# %%
# import modules
import torch

# %%
import numpy as np
import json
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader, Subset
from torch.nn.utils.rnn import pad_sequence
import os
import csv
from modules_modified import ISAB, SAB, PMA
import pandas as pd
import openpyxl

from sklearn.model_selection import train_test_split
from sklearn.utils.class_weight import compute_class_weight

# %%
# import models
from model import SetTransformerClassifierXY, SetTransformerClassifierXYAdditive, SetTransformerClassifier, DeepSetClassifierXYAdditive, DeepSetClassifierXY, DeepSetClassifier

# %%
# Mappings --------------------------------------------------------
# Map each hold like "A1"…"K18" to an integer 0…(11*18−1)=197
cols = [chr(c) for c in range(ord('A'), ord('K')+1)]
rows = list(range(1, 19))
hold_to_idx = {f"{c}{r}": i for i, (c, r) in enumerate((c, r) for r in rows for c in cols)}


# Map grades "V4"…"V11" 
grade_to_label = {f"V{i}": i - 4 for i in range(4, 12)}  
label_to_grade = {v: k for k, v in grade_to_label.items()}
print(hold_to_idx)
# Out:
# {'A1': 0, 'B1': 1, 'C1': 2, 'D1': 3, 'E1': 4, 'F1': 5, 'G1': 6, 'H1': 7, 'I1': 8, 'J1': 9, 'K1': 10, 'A2': 11, 'B2': 12, 'C2': 13, 'D2': 14, 'E2': 15, 'F2': 16, 'G2': 17, 'H2': 18, 'I2': 19, 'J2': 20, 'K2': 21, 'A3': 22, 'B3': 23, 'C3': 24, 'D3': 25, 'E3': 26, 'F3': 27, 'G3': 28, 'H3': 29, 'I3': 30, 'J3': 31, 'K3': 32, 'A4': 33, 'B4': 34, 'C4': 35, 'D4': 36, 'E4': 37, 'F4': 38, 'G4': 39, 'H4': 40, 'I4': 41, 'J4': 42, 'K4': 43, 'A5': 44, 'B5': 45, 'C5': 46, 'D5': 47, 'E5': 48, 'F5': 49, 'G5': 50, 'H5': 51, 'I5': 52, 'J5': 53, 'K5': 54, 'A6': 55, 'B6': 56, 'C6': 57, 'D6': 58, 'E6': 59, 'F6': 60, 'G6': 61, 'H6': 62, 'I6': 63, 'J6': 64, 'K6': 65, 'A7': 66, 'B7': 67, 'C7': 68, 'D7': 69, 'E7': 70, 'F7': 71, 'G7': 72, 'H7': 73, 'I7': 74, 'J7': 75, 'K7': 76, 'A8': 77, 'B8': 78, 'C8': 79, 'D8': 80, 'E8': 81, 'F8': 82, 'G8': 83, 'H8': 84, 'I8': 85, 'J8': 86, 'K8': 87, 'A9': 88, 'B9': 89, 'C9': 90, 'D9': 91, 'E9': 92, 'F9': 93, 'G9': 94, 'H9': 95, 'I9': 96, 'J9': 97, 'K9': 98, 'A10': 99, 'B10': 100, 'C10': 101, 'D10': 102, 'E10': 103, 'F10': 104, 'G10': 105, 'H10': 106, 'I10': 107, 'J10': 108, 'K10': 109, 'A11': 110, 'B11': 111, 'C11': 112, 'D11': 113, 'E11': 114, 'F11': 115, 'G11': 116, 'H11': 117, 'I11': 118, 'J11': 119, 'K11': 120, 'A12': 121, 'B12': 122, 'C12': 123, 'D12': 124, 'E12': 125, 'F12': 126, 'G12': 127, 'H12': 128, 'I12': 129, 'J12': 130, 'K12': 131, 'A13': 132, 'B13': 133, 'C13': 134, 'D13': 135, 'E13': 136, 'F13': 137, 'G13': 138, 'H13': 139, 'I13': 140, 'J13': 141, 'K13': 142, 'A14': 143, 'B14': 144, 'C14': 145, 'D14': 146, 'E14': 147, 'F14': 148, 'G14': 149, 'H14': 150, 'I14': 151, 'J14': 152, 'K14': 153, 'A15': 154, 'B15': 155, 'C15': 156, 'D15': 157, 'E15': 158, 'F15': 159, 'G15': 160, 'H15': 161, 'I15': 162, 'J15': 163, 'K15': 164, 'A16': 165, 'B16': 166, 'C16': 167, 'D16': 168, 'E16': 169, 'F16': 170, 'G16': 171, 'H16': 172, 'I16': 173, 'J16': 174, 'K16': 175, 'A17': 176, 'B17': 177, 'C17': 178, 'D17': 179, 'E17': 180, 'F17': 181, 'G17': 182, 'H17': 183, 'I17': 184, 'J17': 185, 'K17': 186, 'A18': 187, 'B18': 188, 'C18': 189, 'D18': 190, 'E18': 191, 'F18': 192, 'G18': 193, 'H18': 194, 'I18': 195, 'J18': 196, 'K18': 197}

# %%
# Holds difficulty data --------------------------------------------------------
hold_difficulty = {}
with open("data/hold_difficulty.txt", "r") as f:
    for line in f:
        if ":" not in line:
            continue  # skip malformed line
        hold, rest = line.strip().split(":", 1)
        parts = rest.strip().split(",")
        difficulty = int(parts[0].strip())
        types = [t.strip() for t in parts[1:]]
        hold_difficulty[hold.strip()] = (difficulty, types)
    print("successfully parsed hold difficulty file")

# prepare type vocabulary
unique_types = set()
for _, (_, types) in hold_difficulty.items():
    unique_types.update(types)

type_to_idx = {t: i for i, t in enumerate(sorted(unique_types))}
print(f"successfully prepare type vocabulary")
# Out:
# successfully parsed hold difficulty file
# successfully prepare type vocabulary

# %%
# assign x,y position to each holds -------------------------------
import string

# Board columns A–K → indices 0–10
cols = list(string.ascii_uppercase[:11])  # A–K
# Rows 1–18 → indices 0–17
rows = list(range(1, 19))  # 1–18

# Generate hold_to_coord dictionary
hold_to_coord = {}

for x, col in enumerate(cols):
    for y, row in enumerate(rows):
        hold_name = f"{col}{row}"
        hold_to_coord[hold_name] = (x, y)

print("successfully created (x,y) position to each hold:")
print(hold_to_coord)
# Out:
# successfully created (x,y) position to each hold:
# {'A1': (0, 0), 'A2': (0, 1), 'A3': (0, 2), 'A4': (0, 3), 'A5': (0, 4), 'A6': (0, 5), 'A7': (0, 6), 'A8': (0, 7), 'A9': (0, 8), 'A10': (0, 9), 'A11': (0, 10), 'A12': (0, 11), 'A13': (0, 12), 'A14': (0, 13), 'A15': (0, 14), 'A16': (0, 15), 'A17': (0, 16), 'A18': (0, 17), 'B1': (1, 0), 'B2': (1, 1), 'B3': (1, 2), 'B4': (1, 3), 'B5': (1, 4), 'B6': (1, 5), 'B7': (1, 6), 'B8': (1, 7), 'B9': (1, 8), 'B10': (1, 9), 'B11': (1, 10), 'B12': (1, 11), 'B13': (1, 12), 'B14': (1, 13), 'B15': (1, 14), 'B16': (1, 15), 'B17': (1, 16), 'B18': (1, 17), 'C1': (2, 0), 'C2': (2, 1), 'C3': (2, 2), 'C4': (2, 3), 'C5': (2, 4), 'C6': (2, 5), 'C7': (2, 6), 'C8': (2, 7), 'C9': (2, 8), 'C10': (2, 9), 'C11': (2, 10), 'C12': (2, 11), 'C13': (2, 12), 'C14': (2, 13), 'C15': (2, 14), 'C16': (2, 15), 'C17': (2, 16), 'C18': (2, 17), 'D1': (3, 0), 'D2': (3, 1), 'D3': (3, 2), 'D4': (3, 3), 'D5': (3, 4), 'D6': (3, 5), 'D7': (3, 6), 'D8': (3, 7), 'D9': (3, 8), 'D10': (3, 9), 'D11': (3, 10), 'D12': (3, 11), 'D13': (3, 12), 'D14': (3, 13), 'D15': (3, 14), 'D16': (3, 15), 'D17': (3, 16), 'D18': (3, 17), 'E1': (4, 0), 'E2': (4, 1), 'E3': (4, 2), 'E4': (4, 3), 'E5': (4, 4), 'E6': (4, 5), 'E7': (4, 6), 'E8': (4, 7), 'E9': (4, 8), 'E10': (4, 9), 'E11': (4, 10), 'E12': (4, 11), 'E13': (4, 12), 'E14': (4, 13), 'E15': (4, 14), 'E16': (4, 15), 'E17': (4, 16), 'E18': (4, 17), 'F1': (5, 0), 'F2': (5, 1), 'F3': (5, 2), 'F4': (5, 3), 'F5': (5, 4), 'F6': (5, 5), 'F7': (5, 6), 'F8': (5, 7), 'F9': (5, 8), 'F10': (5, 9), 'F11': (5, 10), 'F12': (5, 11), 'F13': (5, 12), 'F14': (5, 13), 'F15': (5, 14), 'F16': (5, 15), 'F17': (5, 16), 'F18': (5, 17), 'G1': (6, 0), 'G2': (6, 1), 'G3': (6, 2), 'G4': (6, 3), 'G5': (6, 4), 'G6': (6, 5), 'G7': (6, 6), 'G8': (6, 7), 'G9': (6, 8), 'G10': (6, 9), 'G11': (6, 10), 'G12': (6, 11), 'G13': (6, 12), 'G14': (6, 13), 'G15': (6, 14), 'G16': (6, 15), 'G17': (6, 16), 'G18': (6, 17), 'H1': (7, 0), 'H2': (7, 1), 'H3': (7, 2), 'H4': (7, 3), 'H5': (7, 4), 'H6': (7, 5), 'H7': (7, 6), 'H8': (7, 7), 'H9': (7, 8), 'H10': (7, 9), 'H11': (7, 10), 'H12': (7, 11), 'H13': (7, 12), 'H14': (7, 13), 'H15': (7, 14), 'H16': (7, 15), 'H17': (7, 16), 'H18': (7, 17), 'I1': (8, 0), 'I2': (8, 1), 'I3': (8, 2), 'I4': (8, 3), 'I5': (8, 4), 'I6': (8, 5), 'I7': (8, 6), 'I8': (8, 7), 'I9': (8, 8), 'I10': (8, 9), 'I11': (8, 10), 'I12': (8, 11), 'I13': (8, 12), 'I14': (8, 13), 'I15': (8, 14), 'I16': (8, 15), 'I17': (8, 16), 'I18': (8, 17), 'J1': (9, 0), 'J2': (9, 1), 'J3': (9, 2), 'J4': (9, 3), 'J5': (9, 4), 'J6': (9, 5), 'J7': (9, 6), 'J8': (9, 7), 'J9': (9, 8), 'J10': (9, 9), 'J11': (9, 10), 'J12': (9, 11), 'J13': (9, 12), 'J14': (9, 13), 'J15': (9, 14), 'J16': (9, 15), 'J17': (9, 16), 'J18': (9, 17), 'K1': (10, 0), 'K2': (10, 1), 'K3': (10, 2), 'K4': (10, 3), 'K5': (10, 4), 'K6': (10, 5), 'K7': (10, 6), 'K8': (10, 7), 'K9': (10, 8), 'K10': (10, 9), 'K11': (10, 10), 'K12': (10, 11), 'K13': (10, 12), 'K14': (10, 13), 'K15': (10, 14), 'K16': (10, 15), 'K17': (10, 16), 'K18': (10, 17)}

# %%
class MoonBoardDataset(Dataset):
    def __init__(self, json_path, hold_to_idx, grade_to_label, hold_difficulty, type_to_idx, hold_to_coord, max_difficulty=10):
        self.hold_to_idx = hold_to_idx
        self.grade_to_label = grade_to_label
        self.hold_difficulty = hold_difficulty
        self.type_to_idx = type_to_idx
        self.hold_to_coord = hold_to_coord
        self.max_difficulty = max_difficulty

        with open(json_path, 'r') as f:
            self.raw = [json.loads(line) for line in f]

    def __len__(self):
        return len(self.raw)

    def __getitem__(self, idx):
        item = self.raw[idx]
        holds = item['holds']

        hold_idxs = []
        diff_values = []
        type_vecs = []
        xy_coords = []

        for h in holds:
            hold_idxs.append(self.hold_to_idx[h])

            difficulty, types = self.hold_difficulty[h]
            diff_values.append(difficulty / self.max_difficulty)

            # multi-hot vector
            type_vec = torch.zeros(len(self.type_to_idx), dtype=torch.float)
            for t in types:
                if t in self.type_to_idx:
                    type_vec[self.type_to_idx[t]] = 1.0
            type_vecs.append(type_vec)

            # normalized (x, y)
            x, y = self.hold_to_coord[h]
            xy_coords.append(torch.tensor([x / 10.0, y / 17.0], dtype=torch.float))

        return {
            "indices": torch.tensor(hold_idxs, dtype=torch.long),
            "difficulty": torch.tensor(diff_values, dtype=torch.float),
            "type": torch.stack(type_vecs),       # (N, T)
            "xy": torch.stack(xy_coords)          # (N, 2)
        }, torch.tensor(self.grade_to_label[item['grade']], dtype=torch.long)

# %%
# Training loop ------------------------------------------------

# --- Set Hyperparameters ---
json_path = './data/cleaned_moonboard2024_grouped.json'
embed_dim = 64
batch_size = 16
lr = 1e-4
epochs = 20
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# --- Collate Function Factory ---
def make_collate_fn(model_type):
    def collate_fn(batch):
        X_indices = [x["indices"] for x, _ in batch]
        X_difficulty = [x["difficulty"] for x, _ in batch]
        X_type = [x["type"] for x, _ in batch]
        y_batch = [y for _, y in batch]

        X_indices = pad_sequence(X_indices, batch_first=True)
        X_difficulty = pad_sequence(X_difficulty, batch_first=True)
        X_type = pad_sequence(X_type, batch_first=True)
        y_tensor = torch.stack(y_batch)

        if model_type in ["set_transformer_xy", "deepset_xy", "set_transformer_additive", "deepset_xy_additive"]:
            X_xy = [x["xy"] for x, _ in batch]
            X_xy = pad_sequence(X_xy, batch_first=True)
            return (X_indices, X_difficulty, X_type, X_xy), y_tensor
        else:
            return (X_indices,), y_tensor
    return collate_fn

# --- Dataset Loader ---
def load_dataset(json_path, hold_to_idx, grade_to_label, hold_difficulty, type_to_idx, hold_to_coord):
    return MoonBoardDataset(json_path, hold_to_idx, grade_to_label, hold_difficulty, type_to_idx, hold_to_coord)

# --- DataLoader Preparation ---
def prepare_dataloaders(dataset, grade_to_label, batch_size, collate_fn):
    targets = [grade_to_label[item['grade']] for item in dataset.raw]
    class_weights = compute_class_weight(class_weight='balanced', classes=np.unique(targets), y=targets)
    class_weights = torch.tensor(class_weights, dtype=torch.float).to(device)

    train_idx, val_idx = train_test_split(
        list(range(len(dataset))), test_size=0.2, stratify=targets, random_state=42
    )

    train_data = Subset(dataset, train_idx)
    val_data = Subset(dataset, val_idx)

    train_loader = DataLoader(train_data, batch_size=batch_size, shuffle=True, collate_fn=collate_fn)
    val_loader = DataLoader(val_data, batch_size=batch_size, shuffle=False, collate_fn=collate_fn)
    return train_loader, val_loader, class_weights, train_idx, val_idx

# --- Training ---
def train_model(model, train_loader, val_loader, criterion, optimizer, epochs):
    for epoch in range(1, epochs + 1):
        model.train()
        total_loss = 0
        for X, y in train_loader:
            X = tuple(x.to(device) for x in X)
            y = y.to(device)
            if len(X) == 1:
                logits = model(X[0])
            else:
                logits = model(X)
            loss = criterion(logits, y)
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
            total_loss += loss.item()
        print(f"Epoch {epoch:02d} — loss: {total_loss / len(train_loader):.4f}")
    return model

# --- Main Per Model ---
def main(model_type):
    vocab_size = len(hold_to_idx)
    num_classes = len(grade_to_label) - 1
    type_vec_dim = len(type_to_idx)

    if model_type == "set_transformer":
        ModelClass = SetTransformerClassifier
        kwargs = dict(vocab_size=vocab_size, dim_in=embed_dim, num_classes=num_classes)
    elif model_type == "set_transformer_xy":
        ModelClass = SetTransformerClassifierXY
        kwargs = dict(vocab_size=vocab_size, dim_in=embed_dim, num_classes=num_classes, type_vec_dim=type_vec_dim)
    elif model_type == "set_transformer_additive":
        ModelClass = SetTransformerClassifierXYAdditive
        kwargs = dict(vocab_size=vocab_size, feat_dim=embed_dim, num_classes=num_classes, type_vec_dim=type_vec_dim)
    elif model_type == "deepset":
        ModelClass = DeepSetClassifier
        kwargs = dict(vocab_size=vocab_size, dim_in=embed_dim, num_classes=num_classes)
    elif model_type == "deepset_xy":
        ModelClass = DeepSetClassifierXY
        kwargs = dict(vocab_size=vocab_size, dim_in=embed_dim, num_classes=num_classes, type_vec_dim=type_vec_dim)
    elif model_type == "deepset_xy_additive":
        ModelClass = DeepSetClassifierXYAdditive
        kwargs = dict(vocab_size=vocab_size, feat_dim=embed_dim, num_classes=num_classes, type_vec_dim=type_vec_dim)
    else:
        raise ValueError(f"Unknown model_type: {model_type}")

    collate_fn = make_collate_fn(model_type)    
    dataset = load_dataset(json_path, hold_to_idx, grade_to_label, hold_difficulty, type_to_idx, hold_to_coord)
    train_loader, val_loader, class_weights, train_idx, val_idx = prepare_dataloaders(dataset, grade_to_label, batch_size, collate_fn)

    model = ModelClass(**kwargs).to(device)
    criterion = torch.nn.CrossEntropyLoss(weight=class_weights)
    optimizer = torch.optim.Adam(model.parameters(), lr=lr)

    model = train_model(model, train_loader, val_loader, criterion, optimizer, epochs)
    return train_loader, val_loader, model, dataset, train_idx, val_idx

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix
from openpyxl import load_workbook
from openpyxl.drawing.image import Image as XLImage
import csv

# --- plot confusion matrix and save to excel---
def save_confusion_matrix_to_excel(y_true, y_pred, class_labels, model_name, excel_path):
    # Plot confusion matrix and save as image
    cm = confusion_matrix(y_true, y_pred, labels=range(len(class_labels)), normalize='true')
    plt.figure(figsize=(8, 6))
    sns.heatmap(cm, annot=True, fmt=".2f", cmap="Blues", xticklabels=class_labels, yticklabels=class_labels)
    plt.title(f"Confusion Matrix: {model_name}")
    plt.xlabel("Predicted Grade")
    plt.ylabel("Actual Grade")
    plt.tight_layout()
    img_path = f"result/confusion_{model_name}.png"
    plt.savefig(img_path)
    plt.close()

    # Insert image into Excel (new sheet per model)
    wb = load_workbook(excel_path)
    if model_name in wb.sheetnames:
        ws = wb[model_name]
    else:
        ws = wb.create_sheet(title=model_name)
    img = XLImage(img_path)
    ws.add_image(img, "A1")
    wb.save(excel_path)
    print(f"Confusion matrix for {model_name} saved and inserted into {excel_path} (sheet: {model_name})")

# --- export the predictions to excel ---
def _update_outlier_excel(df_all_preds, outlier_filename="result/outlier.xlsx", sheet_name="outliers", threshold=3):
    """
    From a DataFrame with columns [problem_name, y_true, y_pred, diff],
    keep rows where abs(diff) > threshold and aggregate per problem_name:
        - count = number of times flagged
        - y_true = mode (most frequent true label)
        - y_pred_avg = average predicted label across occurrences
    Save to outlier.xlsx.
    """
    # Filter outliers
    outliers = df_all_preds.loc[df_all_preds["diff"].abs() > threshold,
                                ["problem_name", "y_true", "y_pred"]]
    if outliers.empty:
        print(f"No outliers (abs(diff) > {threshold}). Skipped creating outlier.xlsx.")
        return

    # Group & aggregate
    grouped = (outliers
               .groupby("problem_name")
               .agg(
                   count=("problem_name", "size"),
                   y_true=("y_true", lambda x: x.mode().iat[0] if not x.mode().empty else x.iloc[0]),
                   y_pred_avg=("y_pred", lambda x: round(pd.to_numeric(x, errors="coerce").mean(), 2))
               )
               .reset_index())

    # If a previous file exists, merge and accumulate counts
    if os.path.exists(outlier_filename):
        try:
            existing = pd.read_excel(outlier_filename, sheet_name=sheet_name)
            if set(existing.columns) >= {"problem_name", "count", "y_true", "y_pred_avg"}:
                merged = pd.concat([existing, grouped], ignore_index=True)
                # Re-aggregate: sum counts, keep most common y_true, recompute y_pred_avg
                grouped = (merged
                           .groupby("problem_name")
                           .agg(
                               count=("count", "sum"),
                               y_true=("y_true", lambda x: x.mode().iat[0] if not x.mode().empty else x.iloc[0]),
                               y_pred_avg=("y_pred_avg", "mean")
                           )
                           .reset_index())
            # else keep grouped as new
        except Exception:
            pass

    # Save
    with pd.ExcelWriter(outlier_filename, engine="openpyxl", mode="w") as writer:
        grouped.to_excel(writer, sheet_name=sheet_name, index=False)

    print(f"Outliers saved to: {os.path.abspath(outlier_filename)}")


def export_predictions_to_excel(model, dataloader, device, grade_to_label, excel_path, sheet_name):
    results = []
    raw_dataset = dataloader.dataset.dataset  # MoonBoardDataset
    indices = dataloader.dataset.indices      # Subset indices
    label_to_grade = {v: k for k, v in grade_to_label.items()}
    current_index = 0

    model.eval()
    with torch.no_grad():
        for X, y in dataloader:
            if isinstance(X, tuple):
                X = tuple(x.to(device) for x in X)
                preds = model(X[0]).argmax(dim=1) if len(X) == 1 else model(X).argmax(dim=1)
            else:
                X = X.to(device)
                preds = model(X).argmax(dim=1)

            y = y.to(device)
            for i in range(y.size(0)):
                real_label = y[i].item()
                pred_label = preds[i].item()
                dataset_index = indices[current_index]
                current_index += 1
                raw_item = raw_dataset.raw[dataset_index]
                problem_name = raw_item.get('problem_name', f"problem_{dataset_index}")
                results.append({
                    "problem_name": problem_name,
                    "y_true": real_label,  # keep numeric for averaging/aggregation
                    "y_pred": pred_label,
                    "diff": real_label - pred_label
                })

    df = pd.DataFrame(results)

    # 1) Save all predictions into your main Excel file
    with pd.ExcelWriter(excel_path, engine="openpyxl", mode="a", if_sheet_exists="replace") as writer:
        # Convert numeric labels back to grade strings for readability
        df_out = df.copy()
        df_out["y_true"] = df_out["y_true"].map(lambda x: grade_to_label.get(x, f"Unknown({x})"))
        df_out["y_pred"] = df_out["y_pred"].map(lambda x: grade_to_label.get(x, f"Unknown({x})"))
        df_out.to_excel(writer, sheet_name=sheet_name, index=False)
    print(f"Predictions for {sheet_name} exported to: {excel_path}")

    # 2) Create/update outlier.xlsx (problem_name, count, y_true, y_pred_avg)
    _update_outlier_excel(df, outlier_filename="result/outlier.xlsx", sheet_name="outliers", threshold=3)


# --- compute training and validation accuracy ---
def compute_accuracy(model, dataloader, device):
    strict_correct, loose_correct, total = 0, 0, 0
    y_true, y_pred = [], []
    model.eval()
    with torch.no_grad():
        for X, y in dataloader:
            X = tuple(x.to(device) for x in X)
            y = y.to(device)
            if len(X) == 1:
                preds = model(X[0]).argmax(dim=1)
            else:
                preds = model(X).argmax(dim=1)
            total += y.size(0)
            strict_correct += (preds == y).sum().item()
            loose_correct += ((preds - y).abs() <= 1).sum().item()
            y_true.extend(y.cpu().numpy())
            y_pred.extend(preds.cpu().numpy())
    strict_acc = 100.0 * strict_correct / total
    loose_acc = 100.0 * loose_correct / total
    return strict_acc, loose_acc, y_true, y_pred

def log_accuracy_to_csv(model_type, train_strict_acc, train_loose_acc, val_strict_acc, val_loose_acc, csv_path="result/accuracy.csv"):
    file_exists = os.path.isfile(csv_path)
    with open(csv_path, mode='a', newline='') as csvfile:
        writer = csv.writer(csvfile)
        if not file_exists:
            writer.writerow([
                "Model Type",
                "Train Strict Accuracy (%)",
                "Train ±1 Grade Accuracy (%)",
                "Val Strict Accuracy (%)",
                "Val ±1 Grade Accuracy (%)"
            ])
        writer.writerow([
            model_type,
            round(train_strict_acc, 2),
            round(train_loose_acc, 2),
            round(val_strict_acc, 2),
            round(val_loose_acc, 2)
        ])


def compare_models():
    model_types = [
        "set_transformer",
        "deepset",
        "set_transformer_xy",
        "deepset_xy",
        "set_transformer_additive",
        "deepset_xy_additive"
    ]
    results = []
    excel_path = "result/model_comparison_results.xlsx"
    class_labels = [f"V{i}" for i in range(4, 12)]

    for idx, mtype in enumerate(model_types):
        print(f"\n===== Training {mtype} =====")
        train_loader, val_loader, model, dataset, train_idx, val_idx = main(mtype)

        # Compute training accuracy
        train_strict_acc, train_loose_acc, _, _ = compute_accuracy(model, train_loader, device)
        # Compute validation accuracy
        val_strict_acc, val_loose_acc, y_true, y_pred = compute_accuracy(model, val_loader, device)

        # log to CSV
        log_accuracy_to_csv(mtype, train_strict_acc, train_loose_acc, val_strict_acc, val_loose_acc)
        
        results.append({
            "Model Type": mtype,
            "Train Strict Accuracy (%)": round(train_strict_acc, 2),
            "Train ±1 Grade Accuracy (%)": round(train_loose_acc, 2),
            "Val Strict Accuracy (%)": round(val_strict_acc, 2),
            "Val ±1 Grade Accuracy (%)": round(val_loose_acc, 2)
        })

        # Save summary table on first iteration (so Excel file exists)
        if idx == 0:
            df_results = pd.DataFrame(results)
            df_results.to_excel(excel_path, index=False)

        # Save confusion matrix to Excel
        save_confusion_matrix_to_excel(y_true, y_pred, class_labels, mtype, excel_path)

        # Export predictions to Excel (new sheet per model)
        export_predictions_to_excel(model, val_loader, device, grade_to_label, excel_path, sheet_name=f"{mtype}_preds")

    # Save summary table again at the end (with all models)
    df_results = pd.DataFrame(results)
    with pd.ExcelWriter(excel_path, engine="openpyxl", mode="a", if_sheet_exists="replace") as writer:
        df_results.to_excel(writer, sheet_name="Summary", index=False)
    print("\n=== Model Comparison Summary ===")
    print(df_results)

# usage
for i in range(25):
    compare_models()
# Out:
# ===== Training set_transformer =====
# Epoch 01 — loss: 1.7325
# Epoch 02 — loss: 1.6057
# Epoch 03 — loss: 1.5638
# Epoch 04 — loss: 1.5283
# Epoch 05 — loss: 1.4877
# Epoch 06 — loss: 1.4597
# Epoch 07 — loss: 1.4310
# Epoch 08 — loss: 1.3950
# Epoch 09 — loss: 1.3642
# Epoch 10 — loss: 1.3294
# Epoch 11 — loss: 1.2955
# Epoch 12 — loss: 1.2692
# Epoch 13 — loss: 1.2378
# Epoch 14 — loss: 1.2038
# Epoch 15 — loss: 1.1747
# Epoch 16 — loss: 1.1341
# Epoch 17 — loss: 1.1097
# Epoch 18 — loss: 1.0653
# Epoch 19 — loss: 1.0449
# Epoch 20 — loss: 1.0126
# Confusion matrix for set_transformer saved and inserted into result/model_comparison_results.xlsx (sheet: set_transformer)
# Predictions for set_transformer_preds exported to: result/model_comparison_results.xlsx
# Outliers saved to: /Users/patrickdharma/Desktop/university/卒業課題/my_models/set_transformer/classification_model/result/outlier.xlsx
#
# ===== Training deepset =====
# Epoch 01 — loss: 1.8840
# Epoch 02 — loss: 1.6213
# Epoch 03 — loss: 1.5560
# Epoch 04 — loss: 1.5290
# Epoch 05 — loss: 1.5085
# Epoch 06 — loss: 1.4990
# Epoch 07 — loss: 1.4920
# Epoch 08 — loss: 1.4853
# Epoch 09 — loss: 1.4852
# Epoch 10 — loss: 1.4682
# Epoch 11 — loss: 1.4728
# Epoch 12 — loss: 1.4698
# Epoch 13 — loss: 1.4629
# Epoch 14 — loss: 1.4691
# Epoch 15 — loss: 1.4475
# Epoch 16 — loss: 1.4541
# Epoch 17 — loss: 1.4478
# Epoch 18 — loss: 1.4521
# Epoch 19 — loss: 1.4442
# Epoch 20 — loss: 1.4595
# Confusion matrix for deepset saved and inserted into result/model_comparison_results.xlsx (sheet: deepset)
# Predictions for deepset_preds exported to: result/model_comparison_results.xlsx
# Outliers saved to: /Users/patrickdharma/Desktop/university/卒業課題/my_models/set_transformer/classification_model/result/outlier.xlsx
#
# ===== Training set_transformer_xy =====
# Epoch 01 — loss: 1.7291
# Epoch 02 — loss: 1.6013
# Epoch 03 — loss: 1.5584
# Epoch 04 — loss: 1.5278
# Epoch 05 — loss: 1.5016
# Epoch 06 — loss: 1.4645
# Epoch 07 — loss: 1.4330
# Epoch 08 — loss: 1.4029
# Epoch 09 — loss: 1.3686
# Epoch 10 — loss: 1.3319
# Epoch 11 — loss: 1.3027
# Epoch 12 — loss: 1.2616
# Epoch 13 — loss: 1.2314
# Epoch 14 — loss: 1.1879
# Epoch 15 — loss: 1.1566
# Epoch 16 — loss: 1.1173
# Epoch 17 — loss: 1.0864
# Epoch 18 — loss: 1.0542
# Epoch 19 — loss: 1.0121
# Epoch 20 — loss: 0.9845
# Confusion matrix for set_transformer_xy saved and inserted into result/model_comparison_results.xlsx (sheet: set_transformer_xy)
# Predictions for set_transformer_xy_preds exported to: result/model_comparison_results.xlsx
# Outliers saved to: /Users/patrickdharma/Desktop/university/卒業課題/my_models/set_transformer/classification_model/result/outlier.xlsx
#
# ===== Training deepset_xy =====
# Epoch 01 — loss: 1.8777
# Epoch 02 — loss: 1.6176
# Epoch 03 — loss: 1.5545
# Epoch 04 — loss: 1.5271
# Epoch 05 — loss: 1.5086
# Epoch 06 — loss: 1.4952
# Epoch 07 — loss: 1.4821
# Epoch 08 — loss: 1.4825
# Epoch 09 — loss: 1.4748
# Epoch 10 — loss: 1.4682
# Epoch 11 — loss: 1.4653
# Epoch 12 — loss: 1.4690
# Epoch 13 — loss: 1.4607
# Epoch 14 — loss: 1.4579
# Epoch 15 — loss: 1.4603
# Epoch 16 — loss: 1.4592
# Epoch 17 — loss: 1.4538
# Epoch 18 — loss: 1.4496
# Epoch 19 — loss: 1.4450
# Epoch 20 — loss: 1.4482
# Confusion matrix for deepset_xy saved and inserted into result/model_comparison_results.xlsx (sheet: deepset_xy)
# Predictions for deepset_xy_preds exported to: result/model_comparison_results.xlsx
# Outliers saved to: /Users/patrickdharma/Desktop/university/卒業課題/my_models/set_transformer/classification_model/result/outlier.xlsx
#
# ===== Training set_transformer_additive =====
# Epoch 01 — loss: 1.6996
# Epoch 02 — loss: 1.6029
# Epoch 03 — loss: 1.5682
# Epoch 04 — loss: 1.5359
# Epoch 05 — loss: 1.5163
# Epoch 06 — loss: 1.4970
# Epoch 07 — loss: 1.4818
# Epoch 08 — loss: 1.4664
# Epoch 09 — loss: 1.4473
# Epoch 10 — loss: 1.4216
# Epoch 11 — loss: 1.4110
# Epoch 12 — loss: 1.3782
# Epoch 13 — loss: 1.3557
# Epoch 14 — loss: 1.3410
# Epoch 15 — loss: 1.3108
# Epoch 16 — loss: 1.2900
# Epoch 17 — loss: 1.2634
# Epoch 18 — loss: 1.2449
# Epoch 19 — loss: 1.2185
# Epoch 20 — loss: 1.1874
# Confusion matrix for set_transformer_additive saved and inserted into result/model_comparison_results.xlsx (sheet: set_transformer_additive)
# Predictions for set_transformer_additive_preds exported to: result/model_comparison_results.xlsx
# Outliers saved to: /Users/patrickdharma/Desktop/university/卒業課題/my_models/set_transformer/classification_model/result/outlier.xlsx
#
# ===== Training deepset_xy_additive =====
# Epoch 01 — loss: 1.8155
# Epoch 02 — loss: 1.6135
# Epoch 03 — loss: 1.5654
# Epoch 04 — loss: 1.5420
# Epoch 05 — loss: 1.5193
# Epoch 06 — loss: 1.5121
# Epoch 07 — loss: 1.5097
# Epoch 08 — loss: 1.4921
# Epoch 09 — loss: 1.4824
# Epoch 10 — loss: 1.4774
# Epoch 11 — loss: 1.4769
# Epoch 12 — loss: 1.4648
# Epoch 13 — loss: 1.4673
# Epoch 14 — loss: 1.4604
# Epoch 15 — loss: 1.4605
# Epoch 16 — loss: 1.4533
# Epoch 17 — loss: 1.4531
# Epoch 18 — loss: 1.4617
# Epoch 19 — loss: 1.4479
# Epoch 20 — loss: 1.4522
# Confusion matrix for deepset_xy_additive saved and inserted into result/model_comparison_results.xlsx (sheet: deepset_xy_additive)
# Predictions for deepset_xy_additive_preds exported to: result/model_comparison_results.xlsx
# Outliers saved to: /Users/patrickdharma/Desktop/university/卒業課題/my_models/set_transformer/classification_model/result/outlier.xlsx
#
# === Model Comparison Summary ===
#                  Model Type  Train Strict Accuracy (%)  \
# 0           set_transformer                      61.98
# 1                   deepset                      46.37
# 2        set_transformer_xy                      62.42
# 3                deepset_xy                      44.11
# 4  set_transformer_additive                      55.55
# 5       deepset_xy_additive                      44.69
#
#    Train ±1 Grade Accuracy (%)  Val Strict Accuracy (%)  \
# 0                        89.87                    44.56
# 1                        84.01                    44.90
# 2                        88.62                    42.88
# 3                        82.36                    43.50
# 4                        85.75                    44.42
# 5                        84.56                    43.21
#
#    Val ±1 Grade Accuracy (%)
# 0                      81.38
# 1                      81.28
# 2                      78.30
# 3                      80.70
# 4                      80.90
# 5                      82.39
#
# ===== Training set_transformer =====
# Epoch 01 — loss: 1.7455
# Epoch 02 — loss: 1.6098
# Epoch 03 — loss: 1.5656
# Epoch 04 — loss: 1.5305
# Epoch 05 — loss: 1.4966
# Epoch 06 — loss: 1.4626
# Epoch 07 — loss: 1.4343
# Epoch 08 — loss: 1.4119
# Epoch 09 — loss: 1.3854
# Epoch 10 — loss: 1.3504
# Epoch 11 — loss: 1.3269
# Epoch 12 — loss: 1.2844
# Epoch 13 — loss: 1.2547
# Epoch 14 — loss: 1.2151
# Epoch 15 — loss: 1.1851
# Epoch 16 — loss: 1.1439
# Epoch 17 — loss: 1.1165
# Epoch 18 — loss: 1.0725
# Epoch 19 — loss: 1.0369
# Epoch 20 — loss: 0.9937
# Confusion matrix for set_transformer saved and inserted into result/model_comparison_results.xlsx (sheet: set_transformer)
# Predictions for set_transformer_preds exported to: result/model_comparison_results.xlsx
# Outliers saved to: /Users/patrickdharma/Desktop/university/卒業課題/my_models/set_transformer/classification_model/result/outlier.xlsx
#
# ===== Training deepset =====
# Epoch 01 — loss: 1.8850
# Epoch 02 — loss: 1.6257
# Epoch 03 — loss: 1.5520
# Epoch 04 — loss: 1.5230
# Epoch 05 — loss: 1.5012
# Epoch 06 — loss: 1.4899
# Epoch 07 — loss: 1.4817
# Epoch 08 — loss: 1.4744
# Epoch 09 — loss: 1.4683
# Epoch 10 — loss: 1.4648
# Epoch 11 — loss: 1.4643
# Epoch 12 — loss: 1.4557
# Epoch 13 — loss: 1.4548
# Epoch 14 — loss: 1.4517
# Epoch 15 — loss: 1.4473
# Epoch 16 — loss: 1.4538
# Epoch 17 — loss: 1.4462
# Epoch 18 — loss: 1.4447
# Epoch 19 — loss: 1.4433
# Epoch 20 — loss: 1.4386
# Confusion matrix for deepset saved and inserted into result/model_comparison_results.xlsx (sheet: deepset)
# Predictions for deepset_preds exported to: result/model_comparison_results.xlsx
# Outliers saved to: /Users/patrickdharma/Desktop/university/卒業課題/my_models/set_transformer/classification_model/result/outlier.xlsx
#
# ===== Training set_transformer_xy =====
# Epoch 01 — loss: 1.7214
# Epoch 02 — loss: 1.6094
# Epoch 03 — loss: 1.5564
# Epoch 04 — loss: 1.5210
# Epoch 05 — loss: 1.4876
# Epoch 06 — loss: 1.4617
# Epoch 07 — loss: 1.4295
# Epoch 08 — loss: 1.4007
# Epoch 09 — loss: 1.3674
# Epoch 10 — loss: 1.3225
# Epoch 11 — loss: 1.2991
# Epoch 12 — loss: 1.2623
# Epoch 13 — loss: 1.2245
# Epoch 14 — loss: 1.1895
# Epoch 15 — loss: 1.1508
# Epoch 16 — loss: 1.1102
# Epoch 17 — loss: 1.0833
# Epoch 18 — loss: 1.0353
# Epoch 19 — loss: 1.0176
# Epoch 20 — loss: 0.9760
# Confusion matrix for set_transformer_xy saved and inserted into result/model_comparison_results.xlsx (sheet: set_transformer_xy)
# Predictions for set_transformer_xy_preds exported to: result/model_comparison_results.xlsx
# Outliers saved to: /Users/patrickdharma/Desktop/university/卒業課題/my_models/set_transformer/classification_model/result/outlier.xlsx
#
# ===== Training deepset_xy =====
# Epoch 01 — loss: 1.8890
# Epoch 02 — loss: 1.6226
# Epoch 03 — loss: 1.5534
# Epoch 04 — loss: 1.5254
# Epoch 05 — loss: 1.5111
# Epoch 06 — loss: 1.4968
# Epoch 07 — loss: 1.4893
# Epoch 08 — loss: 1.4764
# Epoch 09 — loss: 1.4777
# Epoch 10 — loss: 1.4688
# Epoch 11 — loss: 1.4653
# Epoch 12 — loss: 1.4620
# Epoch 13 — loss: 1.4564
# Epoch 14 — loss: 1.4592
# Epoch 15 — loss: 1.4478
# Epoch 16 — loss: 1.4498
# Epoch 17 — loss: 1.4439
# Epoch 18 — loss: 1.4474
# Epoch 19 — loss: 1.4404
# Epoch 20 — loss: 1.4429
# Confusion matrix for deepset_xy saved and inserted into result/model_comparison_results.xlsx (sheet: deepset_xy)
# Predictions for deepset_xy_preds exported to: result/model_comparison_results.xlsx
# Outliers saved to: /Users/patrickdharma/Desktop/university/卒業課題/my_models/set_transformer/classification_model/result/outlier.xlsx
#
# ===== Training set_transformer_additive =====
# Epoch 01 — loss: 1.6898
# Epoch 02 — loss: 1.5940
# Epoch 03 — loss: 1.5491
# Epoch 04 — loss: 1.5330
# Epoch 05 — loss: 1.5053
# Epoch 06 — loss: 1.4924
# Epoch 07 — loss: 1.4761
# Epoch 08 — loss: 1.4549
# Epoch 09 — loss: 1.4408
# Epoch 10 — loss: 1.4239
# Epoch 11 — loss: 1.3856
# Epoch 12 — loss: 1.3699
# Epoch 13 — loss: 1.3384
# Epoch 14 — loss: 1.3162
# Epoch 15 — loss: 1.2907
# Epoch 16 — loss: 1.2663
# Epoch 17 — loss: 1.2274
# Epoch 18 — loss: 1.1999
# Epoch 19 — loss: 1.1642
# Epoch 20 — loss: 1.1390
# Confusion matrix for set_transformer_additive saved and inserted into result/model_comparison_results.xlsx (sheet: set_transformer_additive)
# Predictions for set_transformer_additive_preds exported to: result/model_comparison_results.xlsx
# Outliers saved to: /Users/patrickdharma/Desktop/university/卒業課題/my_models/set_transformer/classification_model/result/outlier.xlsx
#
# ===== Training deepset_xy_additive =====
# Epoch 01 — loss: 1.8127
# Epoch 02 — loss: 1.6385
# Epoch 03 — loss: 1.5869
# Epoch 04 — loss: 1.5550
# Epoch 05 — loss: 1.5327
# Epoch 06 — loss: 1.5180
# Epoch 07 — loss: 1.5138
# Epoch 08 — loss: 1.5052
# Epoch 09 — loss: 1.4923
# Epoch 10 — loss: 1.4853
# Epoch 11 — loss: 1.4783
# Epoch 12 — loss: 1.4691
# Epoch 13 — loss: 1.4733
# Epoch 14 — loss: 1.4620
# Epoch 15 — loss: 1.4707
# Epoch 16 — loss: 1.4564
# Epoch 17 — loss: 1.4609
# Epoch 18 — loss: 1.4570
# Epoch 19 — loss: 1.4519
# Epoch 20 — loss: 1.4608
# Confusion matrix for deepset_xy_additive saved and inserted into result/model_comparison_results.xlsx (sheet: deepset_xy_additive)
# Predictions for deepset_xy_additive_preds exported to: result/model_comparison_results.xlsx
# Outliers saved to: /Users/patrickdharma/Desktop/university/卒業課題/my_models/set_transformer/classification_model/result/outlier.xlsx
#
# === Model Comparison Summary ===
#                  Model Type  Train Strict Accuracy (%)  \
# 0           set_transformer                      60.15
# 1                   deepset                      42.85
# 2        set_transformer_xy                      62.46
# 3                deepset_xy                      45.59
# 4  set_transformer_additive                      52.91
# 5       deepset_xy_additive                      45.70
#
#    Train ±1 Grade Accuracy (%)  Val Strict Accuracy (%)  \
# 0                        87.56                    42.25
# 1                        80.15                    42.88
# 2                        90.37                    44.56
# 3                        83.50                    43.74
# 4                        82.93                    39.94
# 5                        83.29                    44.23
#
#    Val ±1 Grade Accuracy (%)
# 0                      77.82
# 1                      79.64
# 2                      81.33
# 3                      81.47
# 4                      75.46
# 5                      81.57
#
# ===== Training set_transformer =====
# Epoch 01 — loss: 1.7648
# Epoch 02 — loss: 1.6363
# Epoch 03 — loss: 1.5892
# Epoch 04 — loss: 1.5547
# Epoch 05 — loss: 1.5173
# Epoch 06 — loss: 1.4913
# Epoch 07 — loss: 1.4491
# Epoch 08 — loss: 1.4180
# Epoch 09 — loss: 1.3797
# Epoch 10 — loss: 1.3394
# Epoch 11 — loss: 1.3083
# Epoch 12 — loss: 1.2732
# Epoch 13 — loss: 1.2354
# Epoch 14 — loss: 1.1974
# Epoch 15 — loss: 1.1684
# Epoch 16 — loss: 1.1180
# Epoch 17 — loss: 1.0862
# Epoch 18 — loss: 1.0546
# Epoch 19 — loss: 1.0072
# Epoch 20 — loss: 0.9678
# Confusion matrix for set_transformer saved and inserted into result/model_comparison_results.xlsx (sheet: set_transformer)
# Predictions for set_transformer_preds exported to: result/model_comparison_results.xlsx
# Outliers saved to: /Users/patrickdharma/Desktop/university/卒業課題/my_models/set_transformer/classification_model/result/outlier.xlsx
#
# ===== Training deepset =====
# Epoch 01 — loss: 1.8768
# Epoch 02 — loss: 1.6106
# Epoch 03 — loss: 1.5481
# Epoch 04 — loss: 1.5198
# Epoch 05 — loss: 1.5022
# Epoch 06 — loss: 1.4976
# Epoch 07 — loss: 1.4860
# Epoch 08 — loss: 1.4784
# Epoch 09 — loss: 1.4721
# Epoch 10 — loss: 1.4685
# Epoch 11 — loss: 1.4596
# Epoch 12 — loss: 1.4674
# Epoch 13 — loss: 1.4540
# Epoch 14 — loss: 1.4563
# Epoch 15 — loss: 1.4552
# Epoch 16 — loss: 1.4590
# Epoch 17 — loss: 1.4469
# Epoch 18 — loss: 1.4531
# Epoch 19 — loss: 1.4477
# Epoch 20 — loss: 1.4429
# Confusion matrix for deepset saved and inserted into result/model_comparison_results.xlsx (sheet: deepset)
# Predictions for deepset_preds exported to: result/model_comparison_results.xlsx
# Outliers saved to: /Users/patrickdharma/Desktop/university/卒業課題/my_models/set_transformer/classification_model/result/outlier.xlsx
#
# ===== Training set_transformer_xy =====
# Epoch 01 — loss: 1.7471
# Epoch 02 — loss: 1.6047
# Epoch 03 — loss: 1.5650
# Epoch 04 — loss: 1.5207
# Epoch 05 — loss: 1.4962
# Epoch 06 — loss: 1.4618
# Epoch 07 — loss: 1.4369
# Epoch 08 — loss: 1.4121
# Epoch 09 — loss: 1.3820
# Epoch 10 — loss: 1.3386
# Epoch 11 — loss: 1.3172
# Epoch 12 — loss: 1.2795
# Epoch 13 — loss: 1.2390
# Epoch 14 — loss: 1.1995
# Epoch 15 — loss: 1.1635
# Epoch 16 — loss: 1.1285
# Epoch 17 — loss: 1.0892
# Epoch 18 — loss: 1.0544
# Epoch 19 — loss: 1.0123
# Epoch 20 — loss: 0.9773
# Confusion matrix for set_transformer_xy saved and inserted into result/model_comparison_results.xlsx (sheet: set_transformer_xy)
# Predictions for set_transformer_xy_preds exported to: result/model_comparison_results.xlsx
# Outliers saved to: /Users/patrickdharma/Desktop/university/卒業課題/my_models/set_transformer/classification_model/result/outlier.xlsx
#
# ===== Training deepset_xy =====
# Epoch 01 — loss: 1.8715
# Epoch 02 — loss: 1.6060
# Epoch 03 — loss: 1.5545
# Epoch 04 — loss: 1.5331
# Epoch 05 — loss: 1.5130
# Epoch 06 — loss: 1.5041
# Epoch 07 — loss: 1.4915
# Epoch 08 — loss: 1.4851
# Epoch 09 — loss: 1.4864
# Epoch 10 — loss: 1.4804
# Epoch 11 — loss: 1.4716
# Epoch 12 — loss: 1.4671
# Epoch 13 — loss: 1.4635
# Epoch 14 — loss: 1.4605
# Epoch 15 — loss: 1.4631
# Epoch 16 — loss: 1.4570
# Epoch 17 — loss: 1.4549
# Epoch 18 — loss: 1.4498
# Epoch 19 — loss: 1.4456
# Epoch 20 — loss: 1.4449
# Confusion matrix for deepset_xy saved and inserted into result/model_comparison_results.xlsx (sheet: deepset_xy)
# Predictions for deepset_xy_preds exported to: result/model_comparison_results.xlsx
# Outliers saved to: /Users/patrickdharma/Desktop/university/卒業課題/my_models/set_transformer/classification_model/result/outlier.xlsx
#
# ===== Training set_transformer_additive =====
# Epoch 01 — loss: 1.7292
# Epoch 02 — loss: 1.6275
# Epoch 03 — loss: 1.5828
# Epoch 04 — loss: 1.5633
# Epoch 05 — loss: 1.5407
# Epoch 06 — loss: 1.5320
# Epoch 07 — loss: 1.5006
# Epoch 08 — loss: 1.4856
# Epoch 09 — loss: 1.4726
# Epoch 10 — loss: 1.4517
# Epoch 11 — loss: 1.4279
# Epoch 12 — loss: 1.4119
# Epoch 13 — loss: 1.3844
# Epoch 14 — loss: 1.3571
# Epoch 15 — loss: 1.3436
# Epoch 16 — loss: 1.3213
# Epoch 17 — loss: 1.3015
# Epoch 18 — loss: 1.2705
# Epoch 19 — loss: 1.2438
# Epoch 20 — loss: 1.2174
# Confusion matrix for set_transformer_additive saved and inserted into result/model_comparison_results.xlsx (sheet: set_transformer_additive)
# Predictions for set_transformer_additive_preds exported to: result/model_comparison_results.xlsx
# Outliers saved to: /Users/patrickdharma/Desktop/university/卒業課題/my_models/set_transformer/classification_model/result/outlier.xlsx
#
# ===== Training deepset_xy_additive =====
# Epoch 01 — loss: 1.8175
# Epoch 02 — loss: 1.6304
# Epoch 03 — loss: 1.5831
# Epoch 04 — loss: 1.5665
# Epoch 05 — loss: 1.5385
# Epoch 06 — loss: 1.5201
# Epoch 07 — loss: 1.5059
# Epoch 08 — loss: 1.4934
# Epoch 09 — loss: 1.4873
# Epoch 10 — loss: 1.4883
# Epoch 11 — loss: 1.4865
# Epoch 12 — loss: 1.4787
# Epoch 13 — loss: 1.4588
# Epoch 14 — loss: 1.4627
# Epoch 15 — loss: 1.4710
# Epoch 16 — loss: 1.4630
# Epoch 17 — loss: 1.4538
# Epoch 18 — loss: 1.4624
# Epoch 19 — loss: 1.4554
# Epoch 20 — loss: 1.4535
# Confusion matrix for deepset_xy_additive saved and inserted into result/model_comparison_results.xlsx (sheet: deepset_xy_additive)
# Predictions for deepset_xy_additive_preds exported to: result/model_comparison_results.xlsx
# Outliers saved to: /Users/patrickdharma/Desktop/university/卒業課題/my_models/set_transformer/classification_model/result/outlier.xlsx
#
# === Model Comparison Summary ===
#                  Model Type  Train Strict Accuracy (%)  \
# 0           set_transformer                      61.09
# 1                   deepset                      45.18
# 2        set_transformer_xy                      63.79
# 3                deepset_xy                      46.85
# 4  set_transformer_additive                      54.61
# 5       deepset_xy_additive                      45.33
#
#    Train ±1 Grade Accuracy (%)  Val Strict Accuracy (%)  \
# 0                        88.69                    41.67
# 1                        82.89                    43.55
# 2                        91.28                    46.49
# 3                        83.95                    43.84
# 4                        84.31                    43.12
# 5                        81.23                    44.32
#
#    Val ±1 Grade Accuracy (%)
# 0                      79.98
# 1                      81.09
# 2                      82.39
# 3                      81.71
# 4                      80.37
# 5                      79.21
#
# ===== Training set_transformer =====
# Epoch 01 — loss: 1.7589
# Epoch 02 — loss: 1.6286
# Epoch 03 — loss: 1.5796
# Epoch 04 — loss: 1.5449
# Epoch 05 — loss: 1.5063
# Epoch 06 — loss: 1.4749
# Epoch 07 — loss: 1.4514
# Epoch 08 — loss: 1.4102
# Epoch 09 — loss: 1.3809
# Epoch 10 — loss: 1.3526
# Epoch 11 — loss: 1.3176
# Epoch 12 — loss: 1.2904
# Epoch 13 — loss: 1.2601
# Epoch 14 — loss: 1.2234
# Epoch 15 — loss: 1.1915
# Epoch 16 — loss: 1.1541
# Epoch 17 — loss: 1.1095
# Epoch 18 — loss: 1.0729
# Epoch 19 — loss: 1.0309
# Epoch 20 — loss: 1.0093
# Confusion matrix for set_transformer saved and inserted into result/model_comparison_results.xlsx (sheet: set_transformer)
# Predictions for set_transformer_preds exported to: result/model_comparison_results.xlsx
# Outliers saved to: /Users/patrickdharma/Desktop/university/卒業課題/my_models/set_transformer/classification_model/result/outlier.xlsx
#
# ===== Training deepset =====
# Epoch 01 — loss: 1.8948
# Epoch 02 — loss: 1.6313
# Epoch 03 — loss: 1.5682
# Epoch 04 — loss: 1.5412
# Epoch 05 — loss: 1.5241
# Epoch 06 — loss: 1.5124
# Epoch 07 — loss: 1.4975
# Epoch 08 — loss: 1.4901
# Epoch 09 — loss: 1.4804
# Epoch 10 — loss: 1.4760
# Epoch 11 — loss: 1.4773
# Epoch 12 — loss: 1.4683
# Epoch 13 — loss: 1.4632
# Epoch 14 — loss: 1.4591
# Epoch 15 — loss: 1.4656
# Epoch 16 — loss: 1.4577
# Epoch 17 — loss: 1.4567
# Epoch 18 — loss: 1.4547
# Epoch 19 — loss: 1.4464
# Epoch 20 — loss: 1.4462
# Confusion matrix for deepset saved and inserted into result/model_comparison_results.xlsx (sheet: deepset)
# Predictions for deepset_preds exported to: result/model_comparison_results.xlsx
# Outliers saved to: /Users/patrickdharma/Desktop/university/卒業課題/my_models/set_transformer/classification_model/result/outlier.xlsx
#
# ===== Training set_transformer_xy =====
# Epoch 01 — loss: 1.7597
# Epoch 02 — loss: 1.6212
# Epoch 03 — loss: 1.5614
# Epoch 04 — loss: 1.5301
# Epoch 05 — loss: 1.5050
# Epoch 06 — loss: 1.4651
# Epoch 07 — loss: 1.4369
# Epoch 08 — loss: 1.3961
# Epoch 09 — loss: 1.3709
# Epoch 10 — loss: 1.3420
# Epoch 11 — loss: 1.3029
# Epoch 12 — loss: 1.2714
# Epoch 13 — loss: 1.2289
# Epoch 14 — loss: 1.1969
# Epoch 15 — loss: 1.1535
# Epoch 16 — loss: 1.1201
# Epoch 17 — loss: 1.0859
# Epoch 18 — loss: 1.0498
# Epoch 19 — loss: 1.0031
# Epoch 20 — loss: 0.9777
# Confusion matrix for set_transformer_xy saved and inserted into result/model_comparison_results.xlsx (sheet: set_transformer_xy)
# Predictions for set_transformer_xy_preds exported to: result/model_comparison_results.xlsx
# Outliers saved to: /Users/patrickdharma/Desktop/university/卒業課題/my_models/set_transformer/classification_model/result/outlier.xlsx
#
# ===== Training deepset_xy =====
# Epoch 01 — loss: 1.8685
# Epoch 02 — loss: 1.5947
# Epoch 03 — loss: 1.5354
# Epoch 04 — loss: 1.5106
# Epoch 05 — loss: 1.5037
# Epoch 06 — loss: 1.4945
# Epoch 07 — loss: 1.4838
# Epoch 08 — loss: 1.4740
# Epoch 09 — loss: 1.4808
# Epoch 10 — loss: 1.4771
# Epoch 11 — loss: 1.4747
# Epoch 12 — loss: 1.4693
# Epoch 13 — loss: 1.4593
# Epoch 14 — loss: 1.4552
# Epoch 15 — loss: 1.4610
# Epoch 16 — loss: 1.4611
# Epoch 17 — loss: 1.4544
# Epoch 18 — loss: 1.4543
# Epoch 19 — loss: 1.4437
# Epoch 20 — loss: 1.4533
# Confusion matrix for deepset_xy saved and inserted into result/model_comparison_results.xlsx (sheet: deepset_xy)
# Predictions for deepset_xy_preds exported to: result/model_comparison_results.xlsx
# Outliers saved to: /Users/patrickdharma/Desktop/university/卒業課題/my_models/set_transformer/classification_model/result/outlier.xlsx
#
# ===== Training set_transformer_additive =====
# Epoch 01 — loss: 1.7190
# Epoch 02 — loss: 1.6141
# Epoch 03 — loss: 1.5737
# Epoch 04 — loss: 1.5349
# Epoch 05 — loss: 1.5219
# Epoch 06 — loss: 1.4918
# Epoch 07 — loss: 1.4799
# Epoch 08 — loss: 1.4569
# Epoch 09 — loss: 1.4305
# Epoch 10 — loss: 1.4155
# Epoch 11 — loss: 1.3972
# Epoch 12 — loss: 1.3751
# Epoch 13 — loss: 1.3540
# Epoch 14 — loss: 1.3187
# Epoch 15 — loss: 1.2969
# Epoch 16 — loss: 1.2848
# Epoch 17 — loss: 1.2617
# Epoch 18 — loss: 1.2330
# Epoch 19 — loss: 1.2045
# Epoch 20 — loss: 1.1879
# Confusion matrix for set_transformer_additive saved and inserted into result/model_comparison_results.xlsx (sheet: set_transformer_additive)
# Predictions for set_transformer_additive_preds exported to: result/model_comparison_results.xlsx
# Outliers saved to: /Users/patrickdharma/Desktop/university/卒業課題/my_models/set_transformer/classification_model/result/outlier.xlsx
#
# ===== Training deepset_xy_additive =====
# Epoch 01 — loss: 1.8211
# Epoch 02 — loss: 1.6308
# Epoch 03 — loss: 1.5818
# Epoch 04 — loss: 1.5532
# Epoch 05 — loss: 1.5361
# Epoch 06 — loss: 1.5212
# Epoch 07 — loss: 1.5130
# Epoch 08 — loss: 1.4959
# Epoch 09 — loss: 1.4879
# Epoch 10 — loss: 1.4843
# Epoch 11 — loss: 1.4697
# Epoch 12 — loss: 1.4793
# Epoch 13 — loss: 1.4666
# Epoch 14 — loss: 1.4662
# Epoch 15 — loss: 1.4560
# Epoch 16 — loss: 1.4522
# Epoch 17 — loss: 1.4640
# Epoch 18 — loss: 1.4545
# Epoch 19 — loss: 1.4573
# Epoch 20 — loss: 1.4512
# Confusion matrix for deepset_xy_additive saved and inserted into result/model_comparison_results.xlsx (sheet: deepset_xy_additive)
# Predictions for deepset_xy_additive_preds exported to: result/model_comparison_results.xlsx
# Outliers saved to: /Users/patrickdharma/Desktop/university/卒業課題/my_models/set_transformer/classification_model/result/outlier.xlsx
#
# === Model Comparison Summary ===
#                  Model Type  Train Strict Accuracy (%)  \
# 0           set_transformer                      61.75
# 1                   deepset                      44.95
# 2        set_transformer_xy                      64.58
# 3                deepset_xy                      45.29
# 4  set_transformer_additive                      54.17
# 5       deepset_xy_additive                      45.18
#
#    Train ±1 Grade Accuracy (%)  Val Strict Accuracy (%)  \
# 0                        87.94                    43.60
# 1                        82.48                    43.07
# 2                        90.98                    46.63
# 3                        83.11                    44.56
# 4                        85.32                    41.63
# 5                        80.98                    43.50
#
#    Val ±1 Grade Accuracy (%)
# 0                      78.39
# 1                      80.51
# 2                      81.67
# 3                      80.13
# 4                      78.59
# 5                      79.60
#
# ===== Training set_transformer =====
# Epoch 01 — loss: 1.7924
# Epoch 02 — loss: 1.6457
# Epoch 03 — loss: 1.5713
# Epoch 04 — loss: 1.5460
# Epoch 05 — loss: 1.5077
# Epoch 06 — loss: 1.4771
# Epoch 07 — loss: 1.4450
# Epoch 08 — loss: 1.4131
# Epoch 09 — loss: 1.3767
# Epoch 10 — loss: 1.3436
# Epoch 11 — loss: 1.3114
# Epoch 12 — loss: 1.2775
# Epoch 13 — loss: 1.2454
# Epoch 14 — loss: 1.2078
# Epoch 15 — loss: 1.1910
# Epoch 16 — loss: 1.1447
# Epoch 17 — loss: 1.1091
# Epoch 18 — loss: 1.0680
# Epoch 19 — loss: 1.0386
# Epoch 20 — loss: 0.9973
# Confusion matrix for set_transformer saved and inserted into result/model_comparison_results.xlsx (sheet: set_transformer)
# Predictions for set_transformer_preds exported to: result/model_comparison_results.xlsx
# Outliers saved to: /Users/patrickdharma/Desktop/university/卒業課題/my_models/set_transformer/classification_model/result/outlier.xlsx
#
# ===== Training deepset =====
# Epoch 01 — loss: 1.8620
# Epoch 02 — loss: 1.6015
# Epoch 03 — loss: 1.5515
# Epoch 04 — loss: 1.5247
# Epoch 05 — loss: 1.5053
# Epoch 06 — loss: 1.5020
# Epoch 07 — loss: 1.4874
# Epoch 08 — loss: 1.4827
# Epoch 09 — loss: 1.4764
# Epoch 10 — loss: 1.4684
# Epoch 11 — loss: 1.4670
# Epoch 12 — loss: 1.4659
# Epoch 13 — loss: 1.4631
# Epoch 14 — loss: 1.4472
# Epoch 15 — loss: 1.4637
# Epoch 16 — loss: 1.4523
# Epoch 17 — loss: 1.4510
# Epoch 18 — loss: 1.4513
# Epoch 19 — loss: 1.4441
# Epoch 20 — loss: 1.4511
# Confusion matrix for deepset saved and inserted into result/model_comparison_results.xlsx (sheet: deepset)
# Predictions for deepset_preds exported to: result/model_comparison_results.xlsx
# Outliers saved to: /Users/patrickdharma/Desktop/university/卒業課題/my_models/set_transformer/classification_model/result/outlier.xlsx
#
# ===== Training set_transformer_xy =====
# Epoch 01 — loss: 1.7442
# Epoch 02 — loss: 1.6140
# Epoch 03 — loss: 1.5659
# Epoch 04 — loss: 1.5338
# Epoch 05 — loss: 1.4966
# Epoch 06 — loss: 1.4705
# Epoch 07 — loss: 1.4350
# Epoch 08 — loss: 1.4024
# Epoch 09 — loss: 1.3637
# Epoch 10 — loss: 1.3367
# Epoch 11 — loss: 1.2875
# Epoch 12 — loss: 1.2613
# Epoch 13 — loss: 1.2115
# Epoch 14 — loss: 1.1803
# Epoch 15 — loss: 1.1457
# Epoch 16 — loss: 1.1026
# Epoch 17 — loss: 1.0773
# Epoch 18 — loss: 1.0313
# Epoch 19 — loss: 0.9957
# Epoch 20 — loss: 0.9598
# Confusion matrix for set_transformer_xy saved and inserted into result/model_comparison_results.xlsx (sheet: set_transformer_xy)
# Predictions for set_transformer_xy_preds exported to: result/model_comparison_results.xlsx
# Outliers saved to: /Users/patrickdharma/Desktop/university/卒業課題/my_models/set_transformer/classification_model/result/outlier.xlsx
#
# ===== Training deepset_xy =====
# Epoch 01 — loss: 1.8854
# Epoch 02 — loss: 1.6033
# Epoch 03 — loss: 1.5461
# Epoch 04 — loss: 1.5162
# Epoch 05 — loss: 1.5036
# Epoch 06 — loss: 1.4888
# Epoch 07 — loss: 1.4789
# Epoch 08 — loss: 1.4788
# Epoch 09 — loss: 1.4791
# Epoch 10 — loss: 1.4744
# Epoch 11 — loss: 1.4638
# Epoch 12 — loss: 1.4621
# Epoch 13 — loss: 1.4621
# Epoch 14 — loss: 1.4586
# Epoch 15 — loss: 1.4506
# Epoch 16 — loss: 1.4524
# Epoch 17 — loss: 1.4542
# Epoch 18 — loss: 1.4536
# Epoch 19 — loss: 1.4430
# Epoch 20 — loss: 1.4385
# Confusion matrix for deepset_xy saved and inserted into result/model_comparison_results.xlsx (sheet: deepset_xy)
# Predictions for deepset_xy_preds exported to: result/model_comparison_results.xlsx
# Outliers saved to: /Users/patrickdharma/Desktop/university/卒業課題/my_models/set_transformer/classification_model/result/outlier.xlsx
#
# ===== Training set_transformer_additive =====
# Epoch 01 — loss: 1.7138
# Epoch 02 — loss: 1.6239
# Epoch 03 — loss: 1.5885
# Epoch 04 — loss: 1.5466
# Epoch 05 — loss: 1.5321
# Epoch 06 — loss: 1.5050
# Epoch 07 — loss: 1.4836
# Epoch 08 — loss: 1.4768
# Epoch 09 — loss: 1.4371
# Epoch 10 — loss: 1.4275
# Epoch 11 — loss: 1.3944
# Epoch 12 — loss: 1.3810
# Epoch 13 — loss: 1.3638
# Epoch 14 — loss: 1.3350
# Epoch 15 — loss: 1.3098
# Epoch 16 — loss: 1.2791
# Epoch 17 — loss: 1.2609
# Epoch 18 — loss: 1.2356
# Epoch 19 — loss: 1.2011
# Epoch 20 — loss: 1.1755
# Confusion matrix for set_transformer_additive saved and inserted into result/model_comparison_results.xlsx (sheet: set_transformer_additive)
# Predictions for set_transformer_additive_preds exported to: result/model_comparison_results.xlsx
# Outliers saved to: /Users/patrickdharma/Desktop/university/卒業課題/my_models/set_transformer/classification_model/result/outlier.xlsx
#
# ===== Training deepset_xy_additive =====
# Epoch 01 — loss: 1.8061
# Epoch 02 — loss: 1.6401
# Epoch 03 — loss: 1.6020
# Epoch 04 — loss: 1.5663
# Epoch 05 — loss: 1.5429
# Epoch 06 — loss: 1.5192
# Epoch 07 — loss: 1.5097
# Epoch 08 — loss: 1.5046
# Epoch 09 — loss: 1.4914
# Epoch 10 — loss: 1.4869
# Epoch 11 — loss: 1.4891
# Epoch 12 — loss: 1.4748
# Epoch 13 — loss: 1.4720
# Epoch 14 — loss: 1.4720
# Epoch 15 — loss: 1.4656
# Epoch 16 — loss: 1.4634
# Epoch 17 — loss: 1.4650
# Epoch 18 — loss: 1.4581
# Epoch 19 — loss: 1.4577
# Epoch 20 — loss: 1.4533
# Confusion matrix for deepset_xy_additive saved and inserted into result/model_comparison_results.xlsx (sheet: deepset_xy_additive)
# Predictions for deepset_xy_additive_preds exported to: result/model_comparison_results.xlsx
# Outliers saved to: /Users/patrickdharma/Desktop/university/卒業課題/my_models/set_transformer/classification_model/result/outlier.xlsx
#
# === Model Comparison Summary ===
#                  Model Type  Train Strict Accuracy (%)  \
# 0           set_transformer                      61.93
# 1                   deepset                      45.22
# 2        set_transformer_xy                      61.80
# 3                deepset_xy                      45.13
# 4  set_transformer_additive                      56.55
# 5       deepset_xy_additive                      46.42
#
#    Train ±1 Grade Accuracy (%)  Val Strict Accuracy (%)  \
# 0                        87.57                    41.72
# 1                        83.60                    43.31
# 2                        87.55                    43.60
# 3                        82.91                    44.51
# 4                        86.52                    44.37
# 5                        83.49                    45.28
#
#    Val ±1 Grade Accuracy (%)
# 0                      76.13
# 1                      81.28
# 2                      78.49
# 3                      80.22
# 4                      81.47
# 5                      80.37
#
# ===== Training set_transformer =====
# Epoch 01 — loss: 1.7756
# Epoch 02 — loss: 1.6501
# Epoch 03 — loss: 1.5915
# Epoch 04 — loss: 1.5567
# Epoch 05 — loss: 1.5098
# Epoch 06 — loss: 1.4744
# Epoch 07 — loss: 1.4424
# Epoch 08 — loss: 1.4065
# Epoch 09 — loss: 1.3743
# Epoch 10 — loss: 1.3470
# Epoch 11 — loss: 1.3121
# Epoch 12 — loss: 1.2717
# Epoch 13 — loss: 1.2345
# Epoch 14 — loss: 1.1951
# Epoch 15 — loss: 1.1679
# Epoch 16 — loss: 1.1222
# Epoch 17 — loss: 1.0927
# Epoch 18 — loss: 1.0579
# Epoch 19 — loss: 1.0249
# Epoch 20 — loss: 0.9953
# Confusion matrix for set_transformer saved and inserted into result/model_comparison_results.xlsx (sheet: set_transformer)
# Predictions for set_transformer_preds exported to: result/model_comparison_results.xlsx
# Outliers saved to: /Users/patrickdharma/Desktop/university/卒業課題/my_models/set_transformer/classification_model/result/outlier.xlsx
#
# ===== Training deepset =====
# Epoch 01 — loss: 1.8605
# Epoch 02 — loss: 1.6026
# Epoch 03 — loss: 1.5483
# Epoch 04 — loss: 1.5262
# Epoch 05 — loss: 1.5056
# Epoch 06 — loss: 1.4996
# Epoch 07 — loss: 1.4912
# Epoch 08 — loss: 1.4838
# Epoch 09 — loss: 1.4753
# Epoch 10 — loss: 1.4745
# Epoch 11 — loss: 1.4731
# Epoch 12 — loss: 1.4620
# Epoch 13 — loss: 1.4599
# Epoch 14 — loss: 1.4573
# Epoch 15 — loss: 1.4621
# Epoch 16 — loss: 1.4535
# Epoch 17 — loss: 1.4496
# Epoch 18 — loss: 1.4449
# Epoch 19 — loss: 1.4427
# Epoch 20 — loss: 1.4457
# Confusion matrix for deepset saved and inserted into result/model_comparison_results.xlsx (sheet: deepset)
# Predictions for deepset_preds exported to: result/model_comparison_results.xlsx
# Outliers saved to: /Users/patrickdharma/Desktop/university/卒業課題/my_models/set_transformer/classification_model/result/outlier.xlsx
#
# ===== Training set_transformer_xy =====
# Epoch 01 — loss: 1.7214
# Epoch 02 — loss: 1.5879
# Epoch 03 — loss: 1.5599
# Epoch 04 — loss: 1.5190
# Epoch 05 — loss: 1.5001
# Epoch 06 — loss: 1.4728
# Epoch 07 — loss: 1.4458
# Epoch 08 — loss: 1.4137
# Epoch 09 — loss: 1.3802
# Epoch 10 — loss: 1.3486
# Epoch 11 — loss: 1.3177
# Epoch 12 — loss: 1.2725
# Epoch 13 — loss: 1.2506
# Epoch 14 — loss: 1.2140
# Epoch 15 — loss: 1.1822
# Epoch 16 — loss: 1.1508
# Epoch 17 — loss: 1.1145
# Epoch 18 — loss: 1.0707
# Epoch 19 — loss: 1.0452
# Epoch 20 — loss: 0.9933
# Confusion matrix for set_transformer_xy saved and inserted into result/model_comparison_results.xlsx (sheet: set_transformer_xy)
# Predictions for set_transformer_xy_preds exported to: result/model_comparison_results.xlsx
# Outliers saved to: /Users/patrickdharma/Desktop/university/卒業課題/my_models/set_transformer/classification_model/result/outlier.xlsx
#
# ===== Training deepset_xy =====
# Epoch 01 — loss: 1.8790
# Epoch 02 — loss: 1.6226
# Epoch 03 — loss: 1.5604
# Epoch 04 — loss: 1.5288
# Epoch 05 — loss: 1.5057
# Epoch 06 — loss: 1.5027
# Epoch 07 — loss: 1.4929
# Epoch 08 — loss: 1.4795
# Epoch 09 — loss: 1.4757
# Epoch 10 — loss: 1.4713
# Epoch 11 — loss: 1.4727
# Epoch 12 — loss: 1.4597
# Epoch 13 — loss: 1.4601
# Epoch 14 — loss: 1.4500
# Epoch 15 — loss: 1.4592
# Epoch 16 — loss: 1.4492
# Epoch 17 — loss: 1.4490
# Epoch 18 — loss: 1.4504
# Epoch 19 — loss: 1.4406
# Epoch 20 — loss: 1.4465
# Confusion matrix for deepset_xy saved and inserted into result/model_comparison_results.xlsx (sheet: deepset_xy)
# Predictions for deepset_xy_preds exported to: result/model_comparison_results.xlsx
# Outliers saved to: /Users/patrickdharma/Desktop/university/卒業課題/my_models/set_transformer/classification_model/result/outlier.xlsx
#
# ===== Training set_transformer_additive =====
# Epoch 01 — loss: 1.7100
# Epoch 02 — loss: 1.5970
# Epoch 03 — loss: 1.5744
# Epoch 04 — loss: 1.5421
# Epoch 05 — loss: 1.5257
# Epoch 06 — loss: 1.5009
# Epoch 07 — loss: 1.4732
# Epoch 08 — loss: 1.4564
# Epoch 09 — loss: 1.4435
# Epoch 10 — loss: 1.4090
# Epoch 11 — loss: 1.3923
# Epoch 12 — loss: 1.3580
# Epoch 13 — loss: 1.3462
# Epoch 14 — loss: 1.3221
# Epoch 15 — loss: 1.2887
# Epoch 16 — loss: 1.2685
# Epoch 17 — loss: 1.2337
# Epoch 18 — loss: 1.2215
# Epoch 19 — loss: 1.1827
# Epoch 20 — loss: 1.1579
# Confusion matrix for set_transformer_additive saved and inserted into result/model_comparison_results.xlsx (sheet: set_transformer_additive)
# Predictions for set_transformer_additive_preds exported to: result/model_comparison_results.xlsx
# Outliers saved to: /Users/patrickdharma/Desktop/university/卒業課題/my_models/set_transformer/classification_model/result/outlier.xlsx
#
# ===== Training deepset_xy_additive =====
# Epoch 01 — loss: 1.8184
# Epoch 02 — loss: 1.6440
# Epoch 03 — loss: 1.6039
# Epoch 04 — loss: 1.5637
# Epoch 05 — loss: 1.5429
# Epoch 06 — loss: 1.5200
# Epoch 07 — loss: 1.5070
# Epoch 08 — loss: 1.5006
# Epoch 09 — loss: 1.4957
# Epoch 10 — loss: 1.4961
# Epoch 11 — loss: 1.4827
# Epoch 12 — loss: 1.4800
# Epoch 13 — loss: 1.4739
# Epoch 14 — loss: 1.4731
# Epoch 15 — loss: 1.4695
# Epoch 16 — loss: 1.4615
# Epoch 17 — loss: 1.4677
# Epoch 18 — loss: 1.4673
# Epoch 19 — loss: 1.4574
# Epoch 20 — loss: 1.4660
# Confusion matrix for deepset_xy_additive saved and inserted into result/model_comparison_results.xlsx (sheet: deepset_xy_additive)
# Predictions for deepset_xy_additive_preds exported to: result/model_comparison_results.xlsx
# Outliers saved to: /Users/patrickdharma/Desktop/university/卒業課題/my_models/set_transformer/classification_model/result/outlier.xlsx
#
# === Model Comparison Summary ===
#                  Model Type  Train Strict Accuracy (%)  \
# 0           set_transformer                      62.09
# 1                   deepset                      46.43
# 2        set_transformer_xy                      61.33
# 3                deepset_xy                      47.36
# 4  set_transformer_additive                      56.15
# 5       deepset_xy_additive                      45.58
#
#    Train ±1 Grade Accuracy (%)  Val Strict Accuracy (%)  \
# 0                        89.44                    45.19
# 1                        84.05                    44.32
# 2                        88.22                    44.37
# 3                        84.42                    45.86
# 4                        86.36                    43.70
# 5                        82.01                    44.08
#
#    Val ±1 Grade Accuracy (%)
# 0                      80.17
# 1                      81.62
# 2                      81.28
# 3                      82.10
# 4                      80.80
# 5                      80.65
#
# ===== Training set_transformer =====
# Epoch 01 — loss: 1.7364
# Epoch 02 — loss: 1.6123
# Epoch 03 — loss: 1.5723
# Epoch 04 — loss: 1.5369
# Epoch 05 — loss: 1.5030
# Epoch 06 — loss: 1.4628
# Epoch 07 — loss: 1.4369
# Epoch 08 — loss: 1.4012
# Epoch 09 — loss: 1.3776
# Epoch 10 — loss: 1.3477
# Epoch 11 — loss: 1.3164
# Epoch 12 — loss: 1.2706
# Epoch 13 — loss: 1.2338
# Epoch 14 — loss: 1.2148
# Epoch 15 — loss: 1.1845
# Epoch 16 — loss: 1.1394
# Epoch 17 — loss: 1.0981
# Epoch 18 — loss: 1.0736
# Epoch 19 — loss: 1.0451
# Epoch 20 — loss: 0.9990
# Confusion matrix for set_transformer saved and inserted into result/model_comparison_results.xlsx (sheet: set_transformer)
# Predictions for set_transformer_preds exported to: result/model_comparison_results.xlsx
# Outliers saved to: /Users/patrickdharma/Desktop/university/卒業課題/my_models/set_transformer/classification_model/result/outlier.xlsx
#
# ===== Training deepset =====
# Epoch 01 — loss: 1.9045
# Epoch 02 — loss: 1.6304
# Epoch 03 — loss: 1.5671
# Epoch 04 — loss: 1.5410
# Epoch 05 — loss: 1.5229
# Epoch 06 — loss: 1.5097
# Epoch 07 — loss: 1.4953
# Epoch 08 — loss: 1.4956
# Epoch 09 — loss: 1.4795
# Epoch 10 — loss: 1.4676
# Epoch 11 — loss: 1.4739
# Epoch 12 — loss: 1.4623
# Epoch 13 — loss: 1.4632
# Epoch 14 — loss: 1.4652
# Epoch 15 — loss: 1.4704
# Epoch 16 — loss: 1.4507
# Epoch 17 — loss: 1.4587
# Epoch 18 — loss: 1.4486
# Epoch 19 — loss: 1.4494
# Epoch 20 — loss: 1.4488
# Confusion matrix for deepset saved and inserted into result/model_comparison_results.xlsx (sheet: deepset)
# Predictions for deepset_preds exported to: result/model_comparison_results.xlsx
# Outliers saved to: /Users/patrickdharma/Desktop/university/卒業課題/my_models/set_transformer/classification_model/result/outlier.xlsx
#
# ===== Training set_transformer_xy =====
# Epoch 01 — loss: 1.7344
# Epoch 02 — loss: 1.5891
# Epoch 03 — loss: 1.5559
# Epoch 04 — loss: 1.5166
# Epoch 05 — loss: 1.4912
# Epoch 06 — loss: 1.4687
# Epoch 07 — loss: 1.4329
# Epoch 08 — loss: 1.3927
# Epoch 09 — loss: 1.3648
# Epoch 10 — loss: 1.3353
# Epoch 11 — loss: 1.2970
# Epoch 12 — loss: 1.2557
# Epoch 13 — loss: 1.2177
# Epoch 14 — loss: 1.1934
# Epoch 15 — loss: 1.1539
# Epoch 16 — loss: 1.1024
# Epoch 17 — loss: 1.0630
# Epoch 18 — loss: 1.0247
# Epoch 19 — loss: 0.9895
# Epoch 20 — loss: 0.9526
# Confusion matrix for set_transformer_xy saved and inserted into result/model_comparison_results.xlsx (sheet: set_transformer_xy)
# Predictions for set_transformer_xy_preds exported to: result/model_comparison_results.xlsx
# Outliers saved to: /Users/patrickdharma/Desktop/university/卒業課題/my_models/set_transformer/classification_model/result/outlier.xlsx
#
# ===== Training deepset_xy =====
# Epoch 01 — loss: 1.8744
# Epoch 02 — loss: 1.6016
# Epoch 03 — loss: 1.5431
# Epoch 04 — loss: 1.5276
# Epoch 05 — loss: 1.5092
# Epoch 06 — loss: 1.4901
# Epoch 07 — loss: 1.4892
# Epoch 08 — loss: 1.4841
# Epoch 09 — loss: 1.4766
# Epoch 10 — loss: 1.4707
# Epoch 11 — loss: 1.4680
# Epoch 12 — loss: 1.4620
# Epoch 13 — loss: 1.4539
# Epoch 14 — loss: 1.4614
# Epoch 15 — loss: 1.4594
# Epoch 16 — loss: 1.4492
# Epoch 17 — loss: 1.4519
# Epoch 18 — loss: 1.4507
# Epoch 19 — loss: 1.4429
# Epoch 20 — loss: 1.4468
# Confusion matrix for deepset_xy saved and inserted into result/model_comparison_results.xlsx (sheet: deepset_xy)
# Predictions for deepset_xy_preds exported to: result/model_comparison_results.xlsx
# Outliers saved to: /Users/patrickdharma/Desktop/university/卒業課題/my_models/set_transformer/classification_model/result/outlier.xlsx
#
# ===== Training set_transformer_additive =====
# Epoch 01 — loss: 1.7175
# Epoch 02 — loss: 1.6172
# Epoch 03 — loss: 1.5789
# Epoch 04 — loss: 1.5544
# Epoch 05 — loss: 1.5368
# Epoch 06 — loss: 1.5213
# Epoch 07 — loss: 1.5027
# Epoch 08 — loss: 1.4714
# Epoch 09 — loss: 1.4508
# Epoch 10 — loss: 1.4304
# Epoch 11 — loss: 1.4182
# Epoch 12 — loss: 1.3934
# Epoch 13 — loss: 1.3756
# Epoch 14 — loss: 1.3537
# Epoch 15 — loss: 1.3431
# Epoch 16 — loss: 1.3128
# Epoch 17 — loss: 1.2959
# Epoch 18 — loss: 1.2769
# Epoch 19 — loss: 1.2425
# Epoch 20 — loss: 1.2246
# Confusion matrix for set_transformer_additive saved and inserted into result/model_comparison_results.xlsx (sheet: set_transformer_additive)
# Predictions for set_transformer_additive_preds exported to: result/model_comparison_results.xlsx
# Outliers saved to: /Users/patrickdharma/Desktop/university/卒業課題/my_models/set_transformer/classification_model/result/outlier.xlsx
#
# ===== Training deepset_xy_additive =====
# Epoch 01 — loss: 1.8032
# Epoch 02 — loss: 1.6226
# Epoch 03 — loss: 1.5718
# Epoch 04 — loss: 1.5458
# Epoch 05 — loss: 1.5270
# Epoch 06 — loss: 1.5151
# Epoch 07 — loss: 1.4956
# Epoch 08 — loss: 1.4904
# Epoch 09 — loss: 1.4818
# Epoch 10 — loss: 1.4741
# Epoch 11 — loss: 1.4802
# Epoch 12 — loss: 1.4689
# Epoch 13 — loss: 1.4656
# Epoch 14 — loss: 1.4651
# Epoch 15 — loss: 1.4582
# Epoch 16 — loss: 1.4620
# Epoch 17 — loss: 1.4534
# Epoch 18 — loss: 1.4477
# Epoch 19 — loss: 1.4529
# Epoch 20 — loss: 1.4469
# Confusion matrix for deepset_xy_additive saved and inserted into result/model_comparison_results.xlsx (sheet: deepset_xy_additive)
# Predictions for deepset_xy_additive_preds exported to: result/model_comparison_results.xlsx
# Outliers saved to: /Users/patrickdharma/Desktop/university/卒業課題/my_models/set_transformer/classification_model/result/outlier.xlsx
#
# === Model Comparison Summary ===
#                  Model Type  Train Strict Accuracy (%)  \
# 0           set_transformer                      61.17
# 1                   deepset                      45.41
# 2        set_transformer_xy                      61.20
# 3                deepset_xy                      46.24
# 4  set_transformer_additive                      50.27
# 5       deepset_xy_additive                      45.42
#
#    Train ±1 Grade Accuracy (%)  Val Strict Accuracy (%)  \
# 0                        88.56                    45.38
# 1                        80.33                    42.73
# 2                        87.27                    44.08
# 3                        82.52                    44.32
# 4                        85.59                    41.34
# 5                        83.55                    43.17
#
#    Val ±1 Grade Accuracy (%)
# 0                      80.75
# 1                      78.87
# 2                      79.60
# 3                      80.99
# 4                      81.38
# 5                      80.61
#
# ===== Training set_transformer =====
# Epoch 01 — loss: 1.7697
# Epoch 02 — loss: 1.6300
# Epoch 03 — loss: 1.5820
# Epoch 04 — loss: 1.5606
# Epoch 05 — loss: 1.5167
# Epoch 06 — loss: 1.4743
# Epoch 07 — loss: 1.4523
# Epoch 08 — loss: 1.4217
# Epoch 09 — loss: 1.3885
# Epoch 10 — loss: 1.3537
# Epoch 11 — loss: 1.3181
# Epoch 12 — loss: 1.2843
# Epoch 13 — loss: 1.2587
# Epoch 14 — loss: 1.2267
# Epoch 15 — loss: 1.1925
# Epoch 16 — loss: 1.1519
# Epoch 17 — loss: 1.1114
# Epoch 18 — loss: 1.0862
# Epoch 19 — loss: 1.0386
# Epoch 20 — loss: 1.0096
# Confusion matrix for set_transformer saved and inserted into result/model_comparison_results.xlsx (sheet: set_transformer)
# Predictions for set_transformer_preds exported to: result/model_comparison_results.xlsx
# Outliers saved to: /Users/patrickdharma/Desktop/university/卒業課題/my_models/set_transformer/classification_model/result/outlier.xlsx
#
# ===== Training deepset =====
# Epoch 01 — loss: 1.9136
# Epoch 02 — loss: 1.6338
# Epoch 03 — loss: 1.5513
# Epoch 04 — loss: 1.5294
# Epoch 05 — loss: 1.5125
# Epoch 06 — loss: 1.5004
# Epoch 07 — loss: 1.4951
# Epoch 08 — loss: 1.4812
# Epoch 09 — loss: 1.4801
# Epoch 10 — loss: 1.4736
# Epoch 11 — loss: 1.4663
# Epoch 12 — loss: 1.4647
# Epoch 13 — loss: 1.4617
# Epoch 14 — loss: 1.4568
# Epoch 15 — loss: 1.4551
# Epoch 16 — loss: 1.4561
# Epoch 17 — loss: 1.4528
# Epoch 18 — loss: 1.4489
# Epoch 19 — loss: 1.4492
# Epoch 20 — loss: 1.4482
# Confusion matrix for deepset saved and inserted into result/model_comparison_results.xlsx (sheet: deepset)
# Predictions for deepset_preds exported to: result/model_comparison_results.xlsx
# Outliers saved to: /Users/patrickdharma/Desktop/university/卒業課題/my_models/set_transformer/classification_model/result/outlier.xlsx
#
# ===== Training set_transformer_xy =====
# Epoch 01 — loss: 1.7345
# Epoch 02 — loss: 1.5886
# Epoch 03 — loss: 1.5420
# Epoch 04 — loss: 1.5149
# Epoch 05 — loss: 1.4858
# Epoch 06 — loss: 1.4429
# Epoch 07 — loss: 1.4149
# Epoch 08 — loss: 1.3845
# Epoch 09 — loss: 1.3603
# Epoch 10 — loss: 1.3214
# Epoch 11 — loss: 1.2952
# Epoch 12 — loss: 1.2564
# Epoch 13 — loss: 1.2196
# Epoch 14 — loss: 1.1822
# Epoch 15 — loss: 1.1472
# Epoch 16 — loss: 1.1082
# Epoch 17 — loss: 1.0737
# Epoch 18 — loss: 1.0361
# Epoch 19 — loss: 0.9959
# Epoch 20 — loss: 0.9566
# Confusion matrix for set_transformer_xy saved and inserted into result/model_comparison_results.xlsx (sheet: set_transformer_xy)
# Predictions for set_transformer_xy_preds exported to: result/model_comparison_results.xlsx
# Outliers saved to: /Users/patrickdharma/Desktop/university/卒業課題/my_models/set_transformer/classification_model/result/outlier.xlsx
#
# ===== Training deepset_xy =====
# Epoch 01 — loss: 1.9001
# Epoch 02 — loss: 1.6147
# Epoch 03 — loss: 1.5412
# Epoch 04 — loss: 1.5197
# Epoch 05 — loss: 1.5049
# Epoch 06 — loss: 1.4878
# Epoch 07 — loss: 1.4849
# Epoch 08 — loss: 1.4840
# Epoch 09 — loss: 1.4736
# Epoch 10 — loss: 1.4702
# Epoch 11 — loss: 1.4666
# Epoch 12 — loss: 1.4665
# Epoch 13 — loss: 1.4502
# Epoch 14 — loss: 1.4561
# Epoch 15 — loss: 1.4513
# Epoch 16 — loss: 1.4547
# Epoch 17 — loss: 1.4554
# Epoch 18 — loss: 1.4502
# Epoch 19 — loss: 1.4444
# Epoch 20 — loss: 1.4433
# Confusion matrix for deepset_xy saved and inserted into result/model_comparison_results.xlsx (sheet: deepset_xy)
# Predictions for deepset_xy_preds exported to: result/model_comparison_results.xlsx
# Outliers saved to: /Users/patrickdharma/Desktop/university/卒業課題/my_models/set_transformer/classification_model/result/outlier.xlsx
#
# ===== Training set_transformer_additive =====
# Epoch 01 — loss: 1.7094
# Epoch 02 — loss: 1.6196
# Epoch 03 — loss: 1.5929
# Epoch 04 — loss: 1.5637
# Epoch 05 — loss: 1.5411
# Epoch 06 — loss: 1.5301
# Epoch 07 — loss: 1.5134
# Epoch 08 — loss: 1.4837
# Epoch 09 — loss: 1.4634
# Epoch 10 — loss: 1.4420
# Epoch 11 — loss: 1.4194
# Epoch 12 — loss: 1.3891
# Epoch 13 — loss: 1.3624
# Epoch 14 — loss: 1.3422
# Epoch 15 — loss: 1.3142
# Epoch 16 — loss: 1.2817
# Epoch 17 — loss: 1.2628
# Epoch 18 — loss: 1.2344
# Epoch 19 — loss: 1.2010
# Epoch 20 — loss: 1.1699
# Confusion matrix for set_transformer_additive saved and inserted into result/model_comparison_results.xlsx (sheet: set_transformer_additive)
# Predictions for set_transformer_additive_preds exported to: result/model_comparison_results.xlsx
# ...
# Epoch 07 — loss: 1.4935
# Epoch 08 — loss: 1.4837
# Epoch 09 — loss: 1.4804
# Epoch 10 — loss: 1.4673
# Epoch 11 — loss: 1.4701
# Epoch 12 — loss: 1.4620
# Epoch 13 — loss: 1.4573
# Epoch 14 — loss: 1.4579
# Epoch 15 — loss: 1.4563
# Epoch 16 — loss: 1.4546
# Epoch 17 — loss: 1.4506
# Epoch 18 — loss: 1.4459
# Epoch 19 — loss: 1.4513
# Epoch 20 — loss: 1.4453
# Confusion matrix for deepset_xy saved and inserted into result/model_comparison_results.xlsx (sheet: deepset_xy)
# Predictions for deepset_xy_preds exported to: result/model_comparison_results.xlsx
# Outliers saved to: /Users/patrickdharma/Desktop/university/卒業課題/my_models/set_transformer/classification_model/result/outlier.xlsx
#
# ===== Training set_transformer_additive =====
# Epoch 01 — loss: 1.7121
# Epoch 02 — loss: 1.6219
# Epoch 03 — loss: 1.5755
# Epoch 04 — loss: 1.5491
# Epoch 05 — loss: 1.5267
# Epoch 06 — loss: 1.5077
# Epoch 07 — loss: 1.4840
# Epoch 08 — loss: 1.4622
# Epoch 09 — loss: 1.4448
# Epoch 10 — loss: 1.4127
# Epoch 11 — loss: 1.3933
# Epoch 12 — loss: 1.3793
# Epoch 13 — loss: 1.3583
# Epoch 14 — loss: 1.3234
# Epoch 15 — loss: 1.2982
# Epoch 16 — loss: 1.2722
# Epoch 17 — loss: 1.2451
# Epoch 18 — loss: 1.2174
# Epoch 19 — loss: 1.1946
# Epoch 20 — loss: 1.1655
# Confusion matrix for set_transformer_additive saved and inserted into result/model_comparison_results.xlsx (sheet: set_transformer_additive)
# Predictions for set_transformer_additive_preds exported to: result/model_comparison_results.xlsx
# Outliers saved to: /Users/patrickdharma/Desktop/university/卒業課題/my_models/set_transformer/classification_model/result/outlier.xlsx
#
# ===== Training deepset_xy_additive =====
# Epoch 01 — loss: 1.7974
# Epoch 02 — loss: 1.6327
# Epoch 03 — loss: 1.5875
# Epoch 04 — loss: 1.5634
# Epoch 05 — loss: 1.5390
# Epoch 06 — loss: 1.5154
# Epoch 07 — loss: 1.5072
# Epoch 08 — loss: 1.4937
# Epoch 09 — loss: 1.4828
# Epoch 10 — loss: 1.4745
# Epoch 11 — loss: 1.4746
# Epoch 12 — loss: 1.4721
# Epoch 13 — loss: 1.4669
# Epoch 14 — loss: 1.4662
# Epoch 15 — loss: 1.4637
# Epoch 16 — loss: 1.4533
# Epoch 17 — loss: 1.4560
# Epoch 18 — loss: 1.4572
# Epoch 19 — loss: 1.4512
# Epoch 20 — loss: 1.4431
# Confusion matrix for deepset_xy_additive saved and inserted into result/model_comparison_results.xlsx (sheet: deepset_xy_additive)
# Predictions for deepset_xy_additive_preds exported to: result/model_comparison_results.xlsx
# Outliers saved to: /Users/patrickdharma/Desktop/university/卒業課題/my_models/set_transformer/classification_model/result/outlier.xlsx
#
# === Model Comparison Summary ===
#                  Model Type  Train Strict Accuracy (%)  \
# 0           set_transformer                      62.88
# 1                   deepset                      42.80
# 2        set_transformer_xy                      62.93
# 3                deepset_xy                      46.77
# 4  set_transformer_additive                      58.54
# 5       deepset_xy_additive                      44.47
#
#    Train ±1 Grade Accuracy (%)  Val Strict Accuracy (%)  \
# 0                        88.42                    44.61
# 1                        79.82                    42.11
# 2                        89.22                    44.66
# 3                        83.73                    44.47
# 4                        88.20                    46.87
# 5                        82.47                    43.89
#
#    Val ±1 Grade Accuracy (%)
# 0                      80.32
# 1                      78.39
# 2                      79.88
# 3                      81.81
# 4                      81.62
# 5                      80.94
#
# ===== Training set_transformer =====
# Epoch 01 — loss: 1.7698
# Epoch 02 — loss: 1.6385
# Epoch 03 — loss: 1.5818
# Epoch 04 — loss: 1.5503
# Epoch 05 — loss: 1.5167
# Epoch 06 — loss: 1.4900
# Epoch 07 — loss: 1.4516
# Epoch 08 — loss: 1.4084
# Epoch 09 — loss: 1.3770
# Epoch 10 — loss: 1.3342
# Epoch 11 — loss: 1.3061
# Epoch 12 — loss: 1.2564
# Epoch 13 — loss: 1.2171
# Epoch 14 — loss: 1.1806
# Epoch 15 — loss: 1.1411
# Epoch 16 — loss: 1.1058
# Epoch 17 — loss: 1.0674
# Epoch 18 — loss: 1.0240
# Epoch 19 — loss: 0.9814
# Epoch 20 — loss: 0.9475
# Confusion matrix for set_transformer saved and inserted into result/model_comparison_results.xlsx (sheet: set_transformer)
# Predictions for set_transformer_preds exported to: result/model_comparison_results.xlsx
# Outliers saved to: /Users/patrickdharma/Desktop/university/卒業課題/my_models/set_transformer/classification_model/result/outlier.xlsx
#
# ===== Training deepset =====
# Epoch 01 — loss: 1.8830
# Epoch 02 — loss: 1.6333
# Epoch 03 — loss: 1.5559
# Epoch 04 — loss: 1.5299
# Epoch 05 — loss: 1.5120
# Epoch 06 — loss: 1.5011
# Epoch 07 — loss: 1.4907
# Epoch 08 — loss: 1.4857
# Epoch 09 — loss: 1.4730
# Epoch 10 — loss: 1.4705
# Epoch 11 — loss: 1.4693
# Epoch 12 — loss: 1.4643
# Epoch 13 — loss: 1.4595
# Epoch 14 — loss: 1.4584
# Epoch 15 — loss: 1.4516
# Epoch 16 — loss: 1.4566
# Epoch 17 — loss: 1.4509
# Epoch 18 — loss: 1.4439
# Epoch 19 — loss: 1.4430
# Epoch 20 — loss: 1.4442
# Confusion matrix for deepset saved and inserted into result/model_comparison_results.xlsx (sheet: deepset)
# Predictions for deepset_preds exported to: result/model_comparison_results.xlsx
# Outliers saved to: /Users/patrickdharma/Desktop/university/卒業課題/my_models/set_transformer/classification_model/result/outlier.xlsx
#
# ===== Training set_transformer_xy =====
# Epoch 01 — loss: 1.7773
# Epoch 02 — loss: 1.6120
# Epoch 03 — loss: 1.5526
# Epoch 04 — loss: 1.5253
# Epoch 05 — loss: 1.5026
# Epoch 06 — loss: 1.4735
# Epoch 07 — loss: 1.4382
# Epoch 08 — loss: 1.4133
# Epoch 09 — loss: 1.3833
# Epoch 10 — loss: 1.3503
# Epoch 11 — loss: 1.3132
# Epoch 12 — loss: 1.2808
# Epoch 13 — loss: 1.2439
# Epoch 14 — loss: 1.2171
# Epoch 15 — loss: 1.1726
# Epoch 16 — loss: 1.1309
# Epoch 17 — loss: 1.1037
# Epoch 18 — loss: 1.0696
# Epoch 19 — loss: 1.0361
# Epoch 20 — loss: 0.9990
# Confusion matrix for set_transformer_xy saved and inserted into result/model_comparison_results.xlsx (sheet: set_transformer_xy)
# Predictions for set_transformer_xy_preds exported to: result/model_comparison_results.xlsx
# Outliers saved to: /Users/patrickdharma/Desktop/university/卒業課題/my_models/set_transformer/classification_model/result/outlier.xlsx
#
# ===== Training deepset_xy =====
# Epoch 01 — loss: 1.9008
# Epoch 02 — loss: 1.6139
# Epoch 03 — loss: 1.5427
# Epoch 04 — loss: 1.5280
# Epoch 05 — loss: 1.5092
# Epoch 06 — loss: 1.5042
# Epoch 07 — loss: 1.4827
# Epoch 08 — loss: 1.4799
# Epoch 09 — loss: 1.4705
# Epoch 10 — loss: 1.4709
# Epoch 11 — loss: 1.4700
# Epoch 12 — loss: 1.4698
# Epoch 13 — loss: 1.4560
# Epoch 14 — loss: 1.4521
# Epoch 15 — loss: 1.4567
# Epoch 16 — loss: 1.4524
# Epoch 17 — loss: 1.4496
# Epoch 18 — loss: 1.4470
# Epoch 19 — loss: 1.4445
# Epoch 20 — loss: 1.4386
# Confusion matrix for deepset_xy saved and inserted into result/model_comparison_results.xlsx (sheet: deepset_xy)
# Predictions for deepset_xy_preds exported to: result/model_comparison_results.xlsx
# Outliers saved to: /Users/patrickdharma/Desktop/university/卒業課題/my_models/set_transformer/classification_model/result/outlier.xlsx
#
# ===== Training set_transformer_additive =====
# Epoch 01 — loss: 1.7079
# Epoch 02 — loss: 1.6239
# Epoch 03 — loss: 1.5797
# Epoch 04 — loss: 1.5627
# Epoch 05 — loss: 1.5439
# Epoch 06 — loss: 1.5072
# Epoch 07 — loss: 1.4861
# Epoch 08 — loss: 1.4736
# Epoch 09 — loss: 1.4519
# Epoch 10 — loss: 1.4319
# Epoch 11 — loss: 1.4016
# Epoch 12 — loss: 1.3819
# Epoch 13 — loss: 1.3547
# Epoch 14 — loss: 1.3252
# Epoch 15 — loss: 1.3083
# Epoch 16 — loss: 1.2749
# Epoch 17 — loss: 1.2584
# Epoch 18 — loss: 1.2283
# Epoch 19 — loss: 1.1966
# Epoch 20 — loss: 1.1764
# Confusion matrix for set_transformer_additive saved and inserted into result/model_comparison_results.xlsx (sheet: set_transformer_additive)
# Predictions for set_transformer_additive_preds exported to: result/model_comparison_results.xlsx
# Outliers saved to: /Users/patrickdharma/Desktop/university/卒業課題/my_models/set_transformer/classification_model/result/outlier.xlsx
#
# ===== Training deepset_xy_additive =====
# Epoch 01 — loss: 1.8193
# Epoch 02 — loss: 1.6332
# Epoch 03 — loss: 1.5888
# Epoch 04 — loss: 1.5568
# Epoch 05 — loss: 1.5325
# Epoch 06 — loss: 1.5203
# Epoch 07 — loss: 1.5044
# Epoch 08 — loss: 1.4918
# Epoch 09 — loss: 1.4839
# Epoch 10 — loss: 1.4707
# Epoch 11 — loss: 1.4680
# Epoch 12 — loss: 1.4713
# Epoch 13 — loss: 1.4681
# Epoch 14 — loss: 1.4576
# Epoch 15 — loss: 1.4584
# Epoch 16 — loss: 1.4535
# Epoch 17 — loss: 1.4551
# Epoch 18 — loss: 1.4529
# Epoch 19 — loss: 1.4470
# Epoch 20 — loss: 1.4416
# Confusion matrix for deepset_xy_additive saved and inserted into result/model_comparison_results.xlsx (sheet: deepset_xy_additive)
# Predictions for deepset_xy_additive_preds exported to: result/model_comparison_results.xlsx
# Outliers saved to: /Users/patrickdharma/Desktop/university/卒業課題/my_models/set_transformer/classification_model/result/outlier.xlsx
#
# === Model Comparison Summary ===
#                  Model Type  Train Strict Accuracy (%)  \
# 0           set_transformer                      63.57
# 1                   deepset                      44.15
# 2        set_transformer_xy                      60.82
# 3                deepset_xy                      44.82
# 4  set_transformer_additive                      58.14
# 5       deepset_xy_additive                      42.14
#
#    Train ±1 Grade Accuracy (%)  Val Strict Accuracy (%)  \
# 0                        89.66                    43.89
# 1                        81.52                    43.26
# 2                        87.59                    45.77
# 3                        82.47                    43.36
# 4                        87.10                    44.85
# 5                        80.77                    41.72
#
#    Val ±1 Grade Accuracy (%)
# 0                      80.41
# 1                      79.84
# 2                      80.90
# 3                      81.09
# 4                      81.86
# 5                      79.45
#
# ===== Training set_transformer =====
# Epoch 01 — loss: 1.7456
# Epoch 02 — loss: 1.6088
# Epoch 03 — loss: 1.5708
# Epoch 04 — loss: 1.5367
# Epoch 05 — loss: 1.5002
# Epoch 06 — loss: 1.4644
# Epoch 07 — loss: 1.4432
# Epoch 08 — loss: 1.4158
# Epoch 09 — loss: 1.3835
# Epoch 10 — loss: 1.3469
# Epoch 11 — loss: 1.3145
# Epoch 12 — loss: 1.2861
# Epoch 13 — loss: 1.2596
# Epoch 14 — loss: 1.2099
# Epoch 15 — loss: 1.1972
# Epoch 16 — loss: 1.1442
# Epoch 17 — loss: 1.1301
# Epoch 18 — loss: 1.0835
# Epoch 19 — loss: 1.0508
# Epoch 20 — loss: 1.0241
# Confusion matrix for set_transformer saved and inserted into result/model_comparison_results.xlsx (sheet: set_transformer)
# Predictions for set_transformer_preds exported to: result/model_comparison_results.xlsx
# Outliers saved to: /Users/patrickdharma/Desktop/university/卒業課題/my_models/set_transformer/classification_model/result/outlier.xlsx
#
# ===== Training deepset =====
# Epoch 01 — loss: 1.8603
# Epoch 02 — loss: 1.5965
# Epoch 03 — loss: 1.5396
# Epoch 04 — loss: 1.5164
# Epoch 05 — loss: 1.5098
# Epoch 06 — loss: 1.4964
# Epoch 07 — loss: 1.4876
# Epoch 08 — loss: 1.4771
# Epoch 09 — loss: 1.4752
# Epoch 10 — loss: 1.4668
# Epoch 11 — loss: 1.4679
# Epoch 12 — loss: 1.4647
# Epoch 13 — loss: 1.4608
# Epoch 14 — loss: 1.4570
# Epoch 15 — loss: 1.4550
# Epoch 16 — loss: 1.4547
# Epoch 17 — loss: 1.4505
# Epoch 18 — loss: 1.4446
# Epoch 19 — loss: 1.4410
# Epoch 20 — loss: 1.4377
# Confusion matrix for deepset saved and inserted into result/model_comparison_results.xlsx (sheet: deepset)
# Predictions for deepset_preds exported to: result/model_comparison_results.xlsx
# Outliers saved to: /Users/patrickdharma/Desktop/university/卒業課題/my_models/set_transformer/classification_model/result/outlier.xlsx
#
# ===== Training set_transformer_xy =====
# Epoch 01 — loss: 1.7219
# Epoch 02 — loss: 1.5945
# Epoch 03 — loss: 1.5460
# Epoch 04 — loss: 1.5110
# Epoch 05 — loss: 1.4796
# Epoch 06 — loss: 1.4556
# Epoch 07 — loss: 1.4210
# Epoch 08 — loss: 1.3874
# Epoch 09 — loss: 1.3559
# Epoch 10 — loss: 1.3191
# Epoch 11 — loss: 1.2850
# Epoch 12 — loss: 1.2551
# Epoch 13 — loss: 1.2106
# Epoch 14 — loss: 1.1834
# Epoch 15 — loss: 1.1362
# Epoch 16 — loss: 1.1028
# Epoch 17 — loss: 1.0683
# Epoch 18 — loss: 1.0465
# Epoch 19 — loss: 1.0085
# Epoch 20 — loss: 0.9574
# Confusion matrix for set_transformer_xy saved and inserted into result/model_comparison_results.xlsx (sheet: set_transformer_xy)
# Predictions for set_transformer_xy_preds exported to: result/model_comparison_results.xlsx
# Outliers saved to: /Users/patrickdharma/Desktop/university/卒業課題/my_models/set_transformer/classification_model/result/outlier.xlsx
#
# ===== Training deepset_xy =====
# Epoch 01 — loss: 1.8773
# Epoch 02 — loss: 1.6167
# Epoch 03 — loss: 1.5590
# Epoch 04 — loss: 1.5395
# Epoch 05 — loss: 1.5136
# Epoch 06 — loss: 1.4990
# Epoch 07 — loss: 1.4977
# Epoch 08 — loss: 1.4888
# Epoch 09 — loss: 1.4851
# Epoch 10 — loss: 1.4799
# Epoch 11 — loss: 1.4759
# Epoch 12 — loss: 1.4661
# Epoch 13 — loss: 1.4684
# Epoch 14 — loss: 1.4583
# Epoch 15 — loss: 1.4544
# Epoch 16 — loss: 1.4569
# Epoch 17 — loss: 1.4537
# Epoch 18 — loss: 1.4523
# Epoch 19 — loss: 1.4510
# Epoch 20 — loss: 1.4506
# Confusion matrix for deepset_xy saved and inserted into result/model_comparison_results.xlsx (sheet: deepset_xy)
# Predictions for deepset_xy_preds exported to: result/model_comparison_results.xlsx
# Outliers saved to: /Users/patrickdharma/Desktop/university/卒業課題/my_models/set_transformer/classification_model/result/outlier.xlsx
#
# ===== Training set_transformer_additive =====
# Epoch 01 — loss: 1.7123
# Epoch 02 — loss: 1.6120
# Epoch 03 — loss: 1.5870
# Epoch 04 — loss: 1.5513
# Epoch 05 — loss: 1.5301
# Epoch 06 — loss: 1.5150
# Epoch 07 — loss: 1.4917
# Epoch 08 — loss: 1.4628
# Epoch 09 — loss: 1.4486
# Epoch 10 — loss: 1.4267
# Epoch 11 — loss: 1.4055
# Epoch 12 — loss: 1.3739
# Epoch 13 — loss: 1.3463
# Epoch 14 — loss: 1.3198
# Epoch 15 — loss: 1.2934
# Epoch 16 — loss: 1.2751
# Epoch 17 — loss: 1.2401
# Epoch 18 — loss: 1.2188
# Epoch 19 — loss: 1.1863
# Epoch 20 — loss: 1.1655
# Confusion matrix for set_transformer_additive saved and inserted into result/model_comparison_results.xlsx (sheet: set_transformer_additive)
# Predictions for set_transformer_additive_preds exported to: result/model_comparison_results.xlsx
# Outliers saved to: /Users/patrickdharma/Desktop/university/卒業課題/my_models/set_transformer/classification_model/result/outlier.xlsx
#
# ===== Training deepset_xy_additive =====
# Epoch 01 — loss: 1.7856
# Epoch 02 — loss: 1.6288
# Epoch 03 — loss: 1.5819
# Epoch 04 — loss: 1.5564
# Epoch 05 — loss: 1.5301
# Epoch 06 — loss: 1.5171
# Epoch 07 — loss: 1.5033
# Epoch 08 — loss: 1.4893
# Epoch 09 — loss: 1.4932
# Epoch 10 — loss: 1.4888
# Epoch 11 — loss: 1.4793
# Epoch 12 — loss: 1.4806
# Epoch 13 — loss: 1.4733
# Epoch 14 — loss: 1.4733
# Epoch 15 — loss: 1.4583
# Epoch 16 — loss: 1.4525
# Epoch 17 — loss: 1.4558
# Epoch 18 — loss: 1.4566
# Epoch 19 — loss: 1.4518
# Epoch 20 — loss: 1.4436
# Confusion matrix for deepset_xy_additive saved and inserted into result/model_comparison_results.xlsx (sheet: deepset_xy_additive)
# Predictions for deepset_xy_additive_preds exported to: result/model_comparison_results.xlsx
# Outliers saved to: /Users/patrickdharma/Desktop/university/卒業課題/my_models/set_transformer/classification_model/result/outlier.xlsx
#
# === Model Comparison Summary ===
#                  Model Type  Train Strict Accuracy (%)  \
# 0           set_transformer                      60.43
# 1                   deepset                      44.90
# 2        set_transformer_xy                      61.95
# 3                deepset_xy                      45.37
# 4  set_transformer_additive                      55.00
# 5       deepset_xy_additive                      47.00
#
#    Train ±1 Grade Accuracy (%)  Val Strict Accuracy (%)  \
# 0                        87.97                    41.48
# 1                        81.93                    43.98
# 2                        88.52                    42.78
# 3                        81.40                    43.94
# 4                        86.36                    42.54
# 5                        83.64                    44.42
#
#    Val ±1 Grade Accuracy (%)
# 0                      78.20
# 1                      79.74
# 2                      80.32
# 3                      80.32
# 4                      81.28
# 5                      81.28

# %%
# evaluate problems
def evaluate_problems(
    model, problem_dict, hold_to_idx, hold_difficulty, type_to_idx, device,
    grade_to_label, hold_to_coord, dataset, train_idx, val_idx, model_type
):
    label_to_grade = {v: k for k, v in grade_to_label.items()}
    print("\n=== MoonBoard Problem Evaluation ===\n")

    for fallback_name, holds in problem_dict.items():
        try:
            hold_idxs = []
            diff_values = []
            type_vecs = []
            xy_coords = []

            for h in holds:
                if h not in hold_difficulty or h not in hold_to_idx or h not in hold_to_coord:
                    raise ValueError(f"[ERROR] Hold '{h}' missing from required dictionaries.")

                hold_idxs.append(hold_to_idx[h])
                difficulty, types = hold_difficulty[h]
                diff_values.append(difficulty / 10.0)

                # Multi-hot vector
                type_vec = torch.zeros(len(type_to_idx), dtype=torch.float)
                for t in types:
                    if t in type_to_idx:
                        type_vec[type_to_idx[t]] = 1.0
                type_vecs.append(type_vec)

                xy_coords.append(torch.tensor([hold_to_coord[h][0] / 10.0, hold_to_coord[h][1] / 17.0], dtype=torch.float))

            # Convert to tensors
            hold_tensor = torch.tensor(hold_idxs, dtype=torch.long).unsqueeze(0).to(device)
            difficulty_tensor = torch.tensor(diff_values, dtype=torch.float).unsqueeze(0).to(device)
            type_tensor = torch.stack(type_vecs).unsqueeze(0).to(device)
            xy_tensor = torch.stack(xy_coords).unsqueeze(0).to(device)

            model.eval()
            with torch.no_grad():
                # --- Select input format based on model_type ---
                if model_type in ["set_transformer_xy", "set_transformer_additive", "deepset_xy"]:
                    input_data = (hold_tensor, difficulty_tensor, type_tensor, xy_tensor)
                elif model_type == "set_transformer":
                    input_data = (hold_tensor,)
                elif model_type == "deepset":
                    input_data = (hold_tensor,)
                else:
                    raise ValueError(f"Unknown model type: {model_type}")

                logits = model(input_data)
                pred_label = logits.argmax(dim=1).item()
                pred_grade = label_to_grade.get(pred_label, f"Unknown({pred_label})")

        except Exception as e:
            print(f"[{fallback_name}] Skipping due to error: {e}")
            continue

        # Search in dataset for match
        found_idx = None
        split = "Not Found"
        setter_grade = "Unknown"
        problem_name = fallback_name

        for idx, item in enumerate(dataset.raw):
            if set(item['holds']) == set(holds):
                found_idx = idx
                setter_grade = item.get('grade', 'Unknown')
                problem_name = item.get('problem_name', fallback_name)
                if found_idx in train_idx:
                    split = "Train"
                elif found_idx in val_idx:
                    split = "Validation"
                else:
                    split = "Found (Unknown Split)"
                break

        holds_with_difficulty = {h: hold_difficulty[h][0] if h in hold_difficulty else "N/A" for h in holds}
        print(f"🔹 Problem Name   : {problem_name}")
        print(f"   Holds Used     : {holds_with_difficulty}")
        print(f"   Setter Grade   : {setter_grade}")
        print(f"   Predicted Grade: {pred_grade}")
        print(f"   Dataset Split  : {split}\n")

named_problems = {
    "Physical V9 Benchmark": ["I18", "J12", "F13", "D10", "E6", "J2"],
    "Triangulation V7": ["A18", "J13", "D16", "E9", "E9", "I4"],
    "warmup crimps": ["I18", "I7", "I9", "I15", "G11", "J14", "J12", "I15", "J14", "H4", "K6"],
    "Ronani V5": ["F18", "I15", "I10", "K9", "K6", "G14", "D16", "E9", "K6", "I15", "E4", "H5"],
    "Don't Fart Alan": ["K18", "J15", "F14", "F13", "D10", "E6", "I7", "I5", "F1"],
    "FINALE MAXI 2025 POCKET 2 V9": ["G3", "F3", "F4", "A6", "A11", "B17", "C9", "D17", "H18"],
    "Khai's V7": ["D18", "A15", "A12", "C9", "E7", "H8", "I6", "E1"],
    "Yums In My Tums V5": ["F18", "G12", "E1", "D13", "I9", "F8", "I2", "F16", "E4", "E6"],
}

group1 = {
    "simma mot strommen": ["A18", "C12", "A9", "B14", "B16", "D1", "F5", "F5"],
    "MAXIMUS!": ["K18", "E3", "K14", "I13", "K7", "I2", "H16", "K11", "G7", "H4"],
    "interstate": ["K18", "H17", "J11", "I9", "G13", "H15", "I5", "I6"],
    "krakatoa pusher": ["H18", "H11", "J8", "F7", "K15", "F4", "J3"],
    "doublement": ["A18", "E16", "F8", "B14", "G8", "E12", "F4", "F3", "F3"],
    "animal instinct": ["F18", "J11", "F9", "H15", "E13", "J11", "I6", "F4"],
    "blue bin day": ["B18", "C18", "A8", "C12", "B15", "A5", "C3"]
}

train_loader, val_loader, model, dataset, train_idx, val_idx = main("set_transformer_additive")

evaluate_problems(
    model=model,
    problem_dict=named_problems,
    hold_to_idx=hold_to_idx,
    hold_difficulty=hold_difficulty,
    type_to_idx=type_to_idx,
    device=device,
    grade_to_label=grade_to_label,
    hold_to_coord=hold_to_coord,
    dataset=dataset,
    train_idx=train_idx,
    val_idx=val_idx,
    model_type="set_transformer_xy"  # or your current model type
)
# Out:
# Epoch 01 — loss: 1.7030
# Epoch 02 — loss: 1.6260
# Epoch 02 — loss: 1.6260
# Epoch 03 — loss: 1.6025
# Epoch 03 — loss: 1.6025
# Epoch 04 — loss: 1.5573
# Epoch 04 — loss: 1.5573
# Epoch 05 — loss: 1.5306
# Epoch 05 — loss: 1.5306
# Epoch 06 — loss: 1.5167
# Epoch 06 — loss: 1.5167
# Epoch 07 — loss: 1.4908
# Epoch 07 — loss: 1.4908
# Epoch 08 — loss: 1.4637
# Epoch 08 — loss: 1.4637
# Epoch 09 — loss: 1.4356
# Epoch 09 — loss: 1.4356
# Epoch 10 — loss: 1.4186
# Epoch 10 — loss: 1.4186
# Epoch 11 — loss: 1.4024
# Epoch 11 — loss: 1.4024
# Epoch 12 — loss: 1.3722
# Epoch 12 — loss: 1.3722
# Epoch 13 — loss: 1.3418
# Epoch 13 — loss: 1.3418
# Epoch 14 — loss: 1.3292
# Epoch 14 — loss: 1.3292
# Epoch 15 — loss: 1.3051
# Epoch 15 — loss: 1.3051
# Epoch 16 — loss: 1.2856
# Epoch 16 — loss: 1.2856
# Epoch 17 — loss: 1.2500
# Epoch 17 — loss: 1.2500
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[11], line 106
#      85 named_problems = {
#      86     "Physical V9 Benchmark": ["I18", "J12", "F13", "D10", "E6", "J2"],
#      87     "Triangulation V7": ["A18", "J13", "D16", "E9", "E9", "I4"],
#    (...)
#      93     "Yums In My Tums V5": ["F18", "G12", "E1", "D13", "I9", "F8", "I2", "F16", "E4", "E6"],
#      94 }
#      96 group1 = {
#      97     "simma mot strommen": ["A18", "C12", "A9", "B14", "B16", "D1", "F5", "F5"],
#      98     "MAXIMUS!": ["K18", "E3", "K14", "I13", "K7", "I2", "H16", "K11", "G7", "H4"],
#    (...)
#     103     "blue bin day": ["B18", "C18", "A8", "C12", "B15", "A5", "C3"]
#     104 }
# --> 106 train_loader, val_loader, model, dataset, train_idx, val_idx = main("set_transformer_additive")
#     108 evaluate_problems(
#     109     model=model,
#     110     problem_dict=named_problems,
#    (...)
#     120     model_type="set_transformer_xy"  # or your current model type
#     121 )
#
# Cell In[9], line 105, in main(model_type)
#     102 criterion = torch.nn.CrossEntropyLoss(weight=class_weights)
#     103 optimizer = torch.optim.Adam(model.parameters(), lr=lr)
# --> 105 model = train_model(model, train_loader, val_loader, criterion, optimizer, epochs)
#     106 return train_loader, val_loader, model, dataset, train_idx, val_idx
#
# Cell In[9], line 67, in train_model(model, train_loader, val_loader, criterion, optimizer, epochs)
#      65 loss = criterion(logits, y)
#      66 optimizer.zero_grad()
# ---> 67 loss.backward()
#      68 optimizer.step()
#      69 total_loss += loss.item()
#
# File ~/anaconda3/envs/sousei/lib/python3.9/site-packages/torch/_tensor.py:522, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     512 if has_torch_function_unary(self):
#     513     return handle_torch_function(
#     514         Tensor.backward,
#     515         (self,),
#    (...)
#     520         inputs=inputs,
#     521     )
# --> 522 torch.autograd.backward(
#     523     self, gradient, retain_graph, create_graph, inputs=inputs
#     524 )
#
# File ~/anaconda3/envs/sousei/lib/python3.9/site-packages/torch/autograd/__init__.py:266, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     261     retain_graph = create_graph
#     263 # The reason we repeat the same comment below is that
#     264 # some Python versions print out the first line of a multi-line function
#     265 # calls in the traceback and some print out the last line
# --> 266 Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     267     tensors,
#     268     grad_tensors_,
#     269     retain_graph,
#     270     create_graph,
#     271     inputs,
#     272     allow_unreachable=True,
#     273     accumulate_grad=True,
#     274 )
#
# KeyboardInterrupt:

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import torch

def visualize_attention_for_problem(model, holds, hold_to_idx, hold_difficulty, type_to_idx, hold_to_coord, device):
    model.eval()

    hold_idxs = []
    diff_values = []
    type_vecs = []
    xy_coords = []

    for h in holds:
        hold_idxs.append(hold_to_idx[h])
        difficulty, types = hold_difficulty[h]
        diff_values.append(difficulty / 10.0)

        type_vec = torch.zeros(len(type_to_idx), dtype=torch.float)
        for t in types:
            if t in type_to_idx:
                type_vec[type_to_idx[t]] = 1.0
        type_vecs.append(type_vec)

        x, y = hold_to_coord[h]
        xy_coords.append([x / 10.0, y / 17.0])

    hold_tensor = torch.tensor(hold_idxs, dtype=torch.long).unsqueeze(0).to(device)
    diff_tensor = torch.tensor(diff_values, dtype=torch.float).unsqueeze(0).to(device)
    type_tensor = torch.stack(type_vecs).unsqueeze(0).to(device)
    xy_tensor = torch.tensor(xy_coords, dtype=torch.float).unsqueeze(0).to(device)

    with torch.no_grad():
        _ = model((hold_tensor, diff_tensor, type_tensor, xy_tensor))

    attn_isab1 = model.encoder[0].mab0.attn_weights.cpu().numpy()
    attn_isab2 = model.encoder[1].mab0.attn_weights.cpu().numpy()

    num_heads = attn_isab1.shape[0]
    fig, axes = plt.subplots(2, num_heads, figsize=(4 * num_heads, 8))
    if num_heads == 1:
        axes = axes.reshape(2, 1)

    for h in range(num_heads):
        sns.heatmap(attn_isab1[h], ax=axes[0, h], cmap="viridis", xticklabels=holds)
        axes[0, h].set_title(f"ISAB1 – Head {h}")
        axes[0, h].set_xlabel("Key (Hold)")
        axes[0, h].set_ylabel("Seed")

        sns.heatmap(attn_isab2[h], ax=axes[1, h], cmap="viridis", xticklabels=holds)
        axes[1, h].set_title(f"ISAB2 – Head {h}")
        axes[1, h].set_xlabel("Key (Hold)")
        axes[1, h].set_ylabel("Seed")

    plt.tight_layout()
    plt.show()

# %%
def get_avg_attention_per_hold(model, holds, hold_to_idx, hold_difficulty, type_to_idx, hold_to_coord, device):
    model.eval()

    hold_idxs = []
    diff_values = []
    type_vecs = []
    xy_coords = []

    for h in holds:
        hold_idxs.append(hold_to_idx[h])
        difficulty, types = hold_difficulty[h]
        diff_values.append(difficulty / 10.0)

        # Multi-hot type vector
        type_vec = torch.zeros(len(type_to_idx), dtype=torch.float)
        for t in types:
            if t in type_to_idx:
                type_vec[type_to_idx[t]] = 1.0
        type_vecs.append(type_vec)

        # XY coordinate
        if h not in hold_to_coord:
            raise ValueError(f"[ERROR] Hold '{h}' has no coordinate in hold_to_coord.")
        x, y = hold_to_coord[h]
        xy_coords.append([x / 10.0, y / 17.0])

    # Build model input tensors
    hold_tensor = torch.tensor(hold_idxs, dtype=torch.long).unsqueeze(0).to(device)       # (1, N)
    diff_tensor = torch.tensor(diff_values, dtype=torch.float).unsqueeze(0).to(device)    # (1, N)
    type_tensor = torch.stack(type_vecs).unsqueeze(0).to(device)                          # (1, N, T)
    xy_tensor = torch.tensor(xy_coords, dtype=torch.float).unsqueeze(0).to(device)        # (1, N, 2)

    with torch.no_grad():
        _ = model((hold_tensor, diff_tensor, type_tensor, xy_tensor))

    attn_weights = model.encoder[0].mab0.attn_weights  # shape: (heads, seeds, holds)
    avg_attn = attn_weights.mean(dim=(0, 1)).cpu().numpy()  # average across heads & seeds → (num_holds,)

    return list(zip(holds, avg_attn))

# %%
# Visualize attention and scores (with XY support)

holds = named_problems["warmup crimps"]

if not hasattr(model.encoder[0], 'mab0') or not hasattr(model.encoder[0].mab0, 'attn_weights'):
    raise ValueError("The provided model does not support attention visualization.")

visualize_attention_for_problem(model, holds, hold_to_idx, hold_difficulty, type_to_idx, hold_to_coord, device)
attention_scores = get_avg_attention_per_hold(model, holds, hold_to_idx, hold_difficulty, type_to_idx, hold_to_coord, device)

# Print sorted scores
attention_scores_sorted = sorted(attention_scores, key=lambda x: x[1], reverse=True)
print("Average Attention Per Hold (sorted):")
for h, score in attention_scores_sorted:
    difficulty = hold_difficulty[h][0] if h in hold_difficulty else "N/A"
    print(f"{h}: {score:.4f} (difficulty: {difficulty})")

# %%
# read accuracy.csv file
import pandas as pd

df = pd.read_csv('./result/accuracy.csv')
# print(df)

filtered_df = df[df['model'] == 'set_transformer_xy']
print(filtered_df)
# Out:
#                  model  strict_train  ±1_train  strict_test  ±1_test
# 2   set_transformer_xy         61.56     87.46        43.98    78.97
# 7   set_transformer_xy         65.11     91.18        45.43    81.86
# 12  set_transformer_xy         59.61     86.25        44.37    79.50
# 17  set_transformer_xy         64.78     91.20        44.37    81.23
# 22  set_transformer_xy         60.65     87.16        42.93    78.87
# 27  set_transformer_xy         64.07     90.74        45.81    81.28
# 32  set_transformer_xy         58.98     87.99        42.35    80.17
# 37  set_transformer_xy         61.40     88.75        44.32    80.51
# 42  set_transformer_xy         63.49     90.59        46.01    81.09
# 47  set_transformer_xy         61.77     88.91        43.31    80.65
